# %%
import os
import json
import pandas as pd
from typing import Dict, Any
from urllib.request import urlretrieve
import seaborn as sns
import matplotlib.pyplot as plt
import math
import numpy as np
import pandas as pd
import geopandas as gpd
import folium
from shapely.geometry import Point
from shapely import wkt
import openrouteservice

relative_path = "../data/landing/domain/"
absolute_path = os.path.abspath(relative_path)

def extract_features(property_id: str, listing_data: Dict[str, Any]) -> Dict[str, Any]:
    features = {'id': property_id}
    
    listing_model = listing_data.get('listingModel', {})
    
    # Extract price
    features['price'] = listing_model.get('price')
    
    # Extract address
    address = listing_model.get('address', {})
    features['street'] = address.get('street')
    features['suburb'] = address.get('suburb')
    features['state'] = address.get('state')
    features['postcode'] = address.get('postcode')
    features['latitude'] = address.get('lat')
    features['longitude'] = address.get('lng')
    
    # Extract other features
    property_features = listing_model.get('features', {})
    features['bedrooms'] = property_features.get('beds')
    features['bathrooms'] = property_features.get('baths')
    features['parking'] = property_features.get('parking')
    features['propertyType'] = property_features.get('propertyType')
    
    return features



# def process_json_files(input_dir: str, output_dir: str, output_filename: str):
#     all_listings = []
    
#     for filename in os.listdir(input_dir):
#         if filename.endswith('.json'):
#             property_id = filename.split('.')[0]  # Get property ID from filename
#             file_path = os.path.join(input_dir, filename)
#             with open(file_path, 'r') as file:
#                 try:
#                     data = json.load(file)
#                     listings_map = data.get('props', {}).get('listingsMap', {})
#                     if property_id in listings_map:
#                         listing_data = listings_map[property_id]
#                         features = extract_features(property_id, listing_data)
#                         all_listings.append(features)
#                         print(f"Processed file: {filename}")
#                     else:
#                         print(f"Property ID {property_id} not found in file: {filename}")
#                 except json.JSONDecodeError:
#                     print(f"Error decoding JSON in file: {filename}")
    

#     df = pd.DataFrame(all_listings)
    
#     # Create output directory if it doesn't exist
#     os.makedirs(output_dir, exist_ok=True)
    
#     # Save DataFrame to CSV
#     output_path = os.path.join(output_dir, output_filename)
#     df.to_csv(output_path, index=False)
#     print(f"CSV file saved to: {output_path}")
#     print(f"Total files processed: {len(all_listings)}")

# # Usage
# input_directory = '../data/landing/domain'
# output_directory = '../data/raw/domain_output'
# output_filename = 'all_listings.csv'

# process_json_files(input_directory, output_directory, output_filename)

# %%
all_listings_df = pd.read_csv('../data/raw/domain_output/all_listings.csv')

# %%
all_listings_df.head()
# Out:
#          id      price                street          suburb state  postcode  \
# 0  16889460    $420.00  27 Westmoreland Road  Sunshine North   VIC      3020
# 1  17188457    $850.00     73 Reynard Street          Coburg   VIC      3058
# 2  17160233  $1,300.00    35 Fairmont Avenue      Camberwell   VIC      3124
# 3  17062496       $580      13 Vesper Avenue         Tarneit   VIC      3029
# 4  17179442    $440.00     9 Red Robin Drive   Winter Valley   VIC      3358
#
#     latitude   longitude  bedrooms  bathrooms  parking propertyType
# 0 -37.774926  144.834817         3          1        2        house
# 1 -37.748181  144.958473         3          2        0        house
# 2 -37.842214  145.071069         4          2        2        house
# 3 -37.835021  144.669242         4          2        2        house
# 4 -37.567505  143.784207         4          2        2        house

# %%
shapefile_path = '../data/raw/PTV/PTV_METRO_TRAIN_STATION.shp'

# Load the shapefile
station_df = gpd.read_file(shapefile_path)

# Display the first few records to understand its structure and ensure data is loaded correctly

# %%
len(station_df)
# Out:
# 220

# %%
rentals_df = all_listings_df.drop_duplicates().dropna(subset=['latitude', 'longitude'])

# %%
rentals_df['propertyType'].value_counts()
# Out:
# propertyType
# house                7541
# apartmentUnitFlat    6034
# townhouse            1559
# studio                214
# villa                  35
# carspace               19
# acreageSemiRural       16
# newHouseLand           16
# newApartments          11
# terrace                 9
# semiDetached            8
# duplex                  5
# vacantLand              4
# rural                   4
# retirement              3
# blockOfUnits            3
# newLand                 1
# Name: count, dtype: int64

# %%
station_df
# Out:
#     STOP_ID   LATITUDE                                          STOP_NAME  \
# 0     19970 -37.781193             Royal Park Railway Station (Parkville)
# 1     19971 -37.788140  Flemington Bridge Railway Station (North Melbo...
# 2     19972 -37.794267         Macaulay Railway Station (North Melbourne)
# 3     19973 -37.807419   North Melbourne Railway Station (West Melbourne)
# 4     19974 -37.788657        Clifton Hill Railway Station (Clifton Hill)
# ..      ...        ...                                                ...
# 215   19965 -37.742345                    Coburg Railway Station (Coburg)
# 216   19966 -37.754485                  Moreland Railway Station (Coburg)
# 217   19967 -37.761242                 Anstey Railway Station (Brunswick)
# 218   19968 -37.767721              Brunswick Railway Station (Brunswick)
# 219   19969 -37.774987                 Jewell Railway Station (Brunswick)
#
#       LONGITUDE TICKETZONE                                          ROUTEUSSP  \
# 0    144.952301          1                                            Upfield
# 1    144.939323          1                                            Upfield
# 2    144.936166          1                                            Upfield
# 3    144.942570          1  Flemington,Sunbury,Upfield,Werribee,Williamsto...
# 4    144.995417          1                                 Mernda,Hurstbridge
# ..          ...        ...                                                ...
# 215  144.963336          1                                            Upfield
# 216  144.961823          1                                            Upfield
# 217  144.960684          1                                            Upfield
# 218  144.959587          1                                            Upfield
# 219  144.958717          1                                            Upfield
#
#                         geometry
# 0    POINT (144.95231 -37.78118)
# 1    POINT (144.93933 -37.78813)
# 2    POINT (144.93617 -37.79425)
# 3    POINT (144.94258 -37.80741)
# 4    POINT (144.99542 -37.78864)
# ..                           ...
# 215  POINT (144.96334 -37.74233)
# 216  POINT (144.96183 -37.75447)
# 217  POINT (144.96069 -37.76123)
# 218  POINT (144.95959 -37.76771)
# 219  POINT (144.95872 -37.77497)
#
# [220 rows x 7 columns]

# %%
Points_for_rentals= rentals_df.apply(lambda x: (x['longitude'], x['latitude']), axis=1)
Points_for_station = station_df.apply(lambda x: (x['LONGITUDE'], x['LATITUDE']), axis=1)

# %%
rentals_df
# Out:
#              id      price                 street          suburb state  \
# 0      16889460    $420.00   27 Westmoreland Road  Sunshine North   VIC
# 1      17188457    $850.00      73 Reynard Street          Coburg   VIC
# 2      17160233  $1,300.00     35 Fairmont Avenue      Camberwell   VIC
# 3      17062496       $580       13 Vesper Avenue         Tarneit   VIC
# 4      17179442    $440.00      9 Red Robin Drive   Winter Valley   VIC
# ...         ...        ...                    ...             ...   ...
# 15480  16644757  $1,050 pw       2/8 Skene Street    Burwood East   VIC
# 15481  16086828       $560        25 Masthead Way  Werribee South   VIC
# 15482  16076685       $700      2/26 Clyde Street  Ferntree Gully   VIC
# 15483  17174571       $835  1/40 Elizabeth Street          Coburg   VIC
# 15484  17171289     $680pw        2 Oxford Street  West Footscray   VIC
#
#        postcode   latitude   longitude  bedrooms  bathrooms  parking  \
# 0          3020 -37.774926  144.834817         3          1        2
# 1          3058 -37.748181  144.958473         3          2        0
# 2          3124 -37.842214  145.071069         4          2        2
# 3          3029 -37.835021  144.669242         4          2        2
# 4          3358 -37.567505  143.784207         4          2        2
# ...         ...        ...         ...       ...        ...      ...
# 15480      3151 -37.856688  145.132631         4          3        2
# 15481      3030 -37.963369  144.707632         4          2        2
# 15482      3156 -37.882581  145.267643         3          2        2
# 15483      3058 -37.737269  144.982527         3          3        2
# 15484      3012 -37.792359  144.877398         3          2        2
#
#             propertyType
# 0                  house
# 1                  house
# 2                  house
# 3                  house
# 4                  house
# ...                  ...
# 15480          townhouse
# 15481              house
# 15482  apartmentUnitFlat
# 15483          townhouse
# 15484          townhouse
#
# [15482 rows x 12 columns]

# %%
rentals_df['geometry'] = Points_for_rentals
station_df['geometry'] = Points_for_station
# Out:
# /var/folders/lh/3pyg7bbj38b6_468dvhq3hnm0000gp/T/ipykernel_47638/741886036.py:2: UserWarning: Geometry column does not contain geometry.
#   station_df['geometry'] = Points_for_station

# %%
rentals_df
# Out:
#              id      price                 street          suburb state  \
# 0      16889460    $420.00   27 Westmoreland Road  Sunshine North   VIC
# 1      17188457    $850.00      73 Reynard Street          Coburg   VIC
# 2      17160233  $1,300.00     35 Fairmont Avenue      Camberwell   VIC
# 3      17062496       $580       13 Vesper Avenue         Tarneit   VIC
# 4      17179442    $440.00      9 Red Robin Drive   Winter Valley   VIC
# ...         ...        ...                    ...             ...   ...
# 15480  16644757  $1,050 pw       2/8 Skene Street    Burwood East   VIC
# 15481  16086828       $560        25 Masthead Way  Werribee South   VIC
# 15482  16076685       $700      2/26 Clyde Street  Ferntree Gully   VIC
# 15483  17174571       $835  1/40 Elizabeth Street          Coburg   VIC
# 15484  17171289     $680pw        2 Oxford Street  West Footscray   VIC
#
#        postcode   latitude   longitude  bedrooms  bathrooms  parking  \
# 0          3020 -37.774926  144.834817         3          1        2
# 1          3058 -37.748181  144.958473         3          2        0
# 2          3124 -37.842214  145.071069         4          2        2
# 3          3029 -37.835021  144.669242         4          2        2
# 4          3358 -37.567505  143.784207         4          2        2
# ...         ...        ...         ...       ...        ...      ...
# 15480      3151 -37.856688  145.132631         4          3        2
# 15481      3030 -37.963369  144.707632         4          2        2
# 15482      3156 -37.882581  145.267643         3          2        2
# 15483      3058 -37.737269  144.982527         3          3        2
# 15484      3012 -37.792359  144.877398         3          2        2
#
#             propertyType                           geometry
# 0                  house         (144.8348174, -37.7749263)
# 1                  house         (144.9584733, -37.7481813)
# 2                  house         (145.0710691, -37.8422139)
# 3                  house          (144.6692424, -37.835021)
# 4                  house         (143.7842071, -37.5675049)
# ...                  ...                                ...
# 15480          townhouse  (145.1326313, -37.85668769999999)
# 15481              house           (144.707632, -37.963369)
# 15482  apartmentUnitFlat          (145.267643, -37.8825813)
# 15483          townhouse          (144.9825267, -37.737269)
# 15484          townhouse         (144.8773982, -37.7923592)
#
# [15482 rows x 13 columns]

# %%
rentals_df.iloc[0]['geometry']
# Out:
# (144.8348174, -37.7749263)

# %%
# 5b3ce3597851110001cf6248b46e26c44d9a4d4f9d0a80a2325cc4f2
client = openrouteservice.Client(key='5b3ce3597851110001cf6248545577b169fa4a4eacc8a470180afc50')

locations = [
       rentals_df.iloc[0]['geometry'],
         station_df.iloc[0]['geometry'],
         station_df.iloc[1]['geometry'],
            station_df.iloc[2]['geometry'],
]

response = client.distance_matrix(
    locations=locations,
    profile='driving-car',   # or 'foot-walking', 'cycling-regular', etc.
    metrics=['distance'],    # Only distance or also 'duration' if needed
    sources=[0],             # Index of the origin point (first in the list)
    destinations=[1,2,3]   # Indices of the destination points
)

# %%
station_df
# Out:
#     STOP_ID   LATITUDE                                          STOP_NAME  \
# 0     19970 -37.781193             Royal Park Railway Station (Parkville)
# 1     19971 -37.788140  Flemington Bridge Railway Station (North Melbo...
# 2     19972 -37.794267         Macaulay Railway Station (North Melbourne)
# 3     19973 -37.807419   North Melbourne Railway Station (West Melbourne)
# 4     19974 -37.788657        Clifton Hill Railway Station (Clifton Hill)
# ..      ...        ...                                                ...
# 215   19965 -37.742345                    Coburg Railway Station (Coburg)
# 216   19966 -37.754485                  Moreland Railway Station (Coburg)
# 217   19967 -37.761242                 Anstey Railway Station (Brunswick)
# 218   19968 -37.767721              Brunswick Railway Station (Brunswick)
# 219   19969 -37.774987                 Jewell Railway Station (Brunswick)
#
#       LONGITUDE TICKETZONE                                          ROUTEUSSP  \
# 0    144.952301          1                                            Upfield
# 1    144.939323          1                                            Upfield
# 2    144.936166          1                                            Upfield
# 3    144.942570          1  Flemington,Sunbury,Upfield,Werribee,Williamsto...
# 4    144.995417          1                                 Mernda,Hurstbridge
# ..          ...        ...                                                ...
# 215  144.963336          1                                            Upfield
# 216  144.961823          1                                            Upfield
# 217  144.960684          1                                            Upfield
# 218  144.959587          1                                            Upfield
# 219  144.958717          1                                            Upfield
#
#                      geometry
# 0    (144.952301, -37.781193)
# 1     (144.939323, -37.78814)
# 2    (144.936166, -37.794267)
# 3     (144.94257, -37.807419)
# 4    (144.995417, -37.788657)
# ..                        ...
# 215  (144.963336, -37.742345)
# 216  (144.961823, -37.754485)
# 217  (144.960684, -37.761242)
# 218  (144.959587, -37.767721)
# 219  (144.958717, -37.774987)
#
# [220 rows x 7 columns]

# %%
list(station_df['STOP_NAME'])
# Out:
# ['Royal Park Railway Station (Parkville)',
#  'Flemington Bridge Railway Station (North Melbourne)',
#  'Macaulay Railway Station (North Melbourne)',
#  'North Melbourne Railway Station (West Melbourne)',
#  'Clifton Hill Railway Station (Clifton Hill)',
#  'Victoria Park Railway Station (Abbotsford)',
#  'Collingwood Railway Station (Abbotsford)',
#  'North Richmond Railway Station (Richmond)',
#  'West Richmond Railway Station (Richmond)',
#  'Jolimont-MCG Railway Station (East Melbourne)',
#  'Macleod Railway Station (Macleod)',
#  'Watsonia Railway Station (Watsonia)',
#  'Greensborough Railway Station (Greensborough)',
#  'Montmorency Railway Station (Montmorency)',
#  'Eltham Railway Station (Eltham)',
#  'Diamond Creek Railway Station (Diamond Creek)',
#  'Wattle Glen Railway Station (Wattle Glen)',
#  'Hurstbridge Railway Station (Hurstbridge)',
#  'Williamstown Railway Station (Williamstown)',
#  'Williamstown Beach Railway Station (Williamstown)',
#  'North Williamstown Railway Station (Williamstown)',
#  'Newport Railway Station (Newport)',
#  'Spotswood Railway Station (Spotswood)',
#  'Yarraville Railway Station (Yarraville)',
#  'Seddon Railway Station (Seddon)',
#  'Watergardens Railway Station (Sydenham)',
#  'Keilor Plains Railway Station (St Albans)',
#  'St Albans Railway Station (St Albans)',
#  'Ginifer Railway Station (St Albans)',
#  'Albion Railway Station (Sunshine North)',
#  'Epping Railway Station (Epping)',
#  'Lalor Railway Station (Lalor)',
#  'Thomastown Railway Station (Thomastown)',
#  'Keon Park Railway Station (Thomastown)',
#  'Ruthven Railway Station (Reservoir)',
#  'Reservoir Railway Station (Reservoir)',
#  'Regent Railway Station (Reservoir)',
#  'Preston Railway Station (Preston)',
#  'Bell Railway Station (Preston)',
#  'Thornbury Railway Station (Thornbury)',
#  'Croxton Railway Station (Northcote)',
#  'Northcote Railway Station (Northcote)',
#  'Merri Railway Station (Northcote)',
#  'Rushall Railway Station (Fitzroy North)',
#  'Sunshine Railway Station (Sunshine)',
#  'Tottenham Railway Station (West Footscray)',
#  'West Footscray Railway Station (West Footscray)',
#  'Middle Footscray Railway Station (Footscray)',
#  'Footscray Railway Station (Footscray)',
#  'South Kensington Railway Station (Kensington)',
#  'Broadmeadows Railway Station (Broadmeadows)',
#  'Jacana Railway Station (Glenroy)',
#  'Glenroy Railway Station (Glenroy)',
#  'Oak Park Railway Station (Oak Park)',
#  'Pascoe Vale Railway Station (Pascoe Vale)',
#  'Strathmore Railway Station (Strathmore)',
#  'Glenbervie Railway Station (Essendon)',
#  'Essendon Railway Station (Essendon)',
#  'Moonee Ponds Railway Station (Moonee Ponds)',
#  'Ascot Vale Railway Station (Ascot Vale)',
#  'Newmarket Railway Station (Flemington)',
#  'Kensington Railway Station (Kensington)',
#  'Box Hill Railway Station (Box Hill)',
#  'Southern Cross Railway Station (Melbourne City)',
#  'Roxburgh Park Railway Station (Roxburgh Park)',
#  'Craigieburn Railway Station (Craigieburn)',
#  'Coolaroo Railway Station (Coolaroo)',
#  'Lynbrook Railway Station (Lynbrook)',
#  'Cardinia Road Railway Station (Pakenham)',
#  'South Morang Railway Station (South Morang)',
#  'Williams Landing Railway Station (Williams Landing)',
#  'Southland Railway Station (Cheltenham)',
#  'Middle Gorge Railway Station (South Morang)',
#  'Hawkstowe Railway Station (South Morang)',
#  'Mernda Railway Station (Mernda)',
#  'Sunbury Railway Station (Sunbury)',
#  'Diggers Rest Railway Station (Diggers Rest)',
#  'Stony Point Railway Station (Crib Point)',
#  'Crib Point Railway Station (Crib Point)',
#  'Morradoo Railway Station (Crib Point)',
#  'Bittern Railway Station (Bittern)',
#  'Hastings Railway Station (Hastings)',
#  'Tyabb Railway Station (Tyabb)',
#  'Somerville Railway Station (Somerville)',
#  'Baxter Railway Station (Baxter)',
#  'Glen Iris Railway Station (Glen Iris)',
#  'Leawarra Railway Station (Frankston)',
#  'Darling Railway Station (Malvern East)',
#  'East Malvern Railway Station (Malvern East)',
#  'Holmesglen Railway Station (Malvern East)',
#  'Jordanville Railway Station (Mount Waverley)',
#  'Flagstaff Railway Station (Melbourne City)',
#  'Melbourne Central Railway Station (Melbourne City)',
#  'Parliament Railway Station (Melbourne City)',
#  'Belgrave Railway Station (Belgrave)',
#  'Tecoma Railway Station (Tecoma)',
#  'Upwey Railway Station (Upwey)',
#  'Alamein Railway Station (Ashburton)',
#  'Ashburton Railway Station (Ashburton)',
#  'Burwood Railway Station (Glen Iris)',
#  'Hartwell Railway Station (Camberwell)',
#  'Willison Railway Station (Camberwell)',
#  'Riversdale Railway Station (Camberwell)',
#  'Camberwell Railway Station (Camberwell)',
#  'Flinders Street Railway Station (Melbourne City)',
#  'Frankston Railway Station (Frankston)',
#  'Kananook Railway Station (Seaford)',
#  'Seaford Railway Station (Seaford)',
#  'Carrum Railway Station (Carrum)',
#  'Bonbeach Railway Station (Bonbeach)',
#  'Chelsea Railway Station (Chelsea)',
#  'Edithvale Railway Station (Edithvale)',
#  'Aspendale Railway Station (Aspendale)',
#  'Mordialloc Railway Station (Mordialloc)',
#  'Parkdale Railway Station (Parkdale)',
#  'Mentone Railway Station (Mentone)',
#  'Cheltenham Railway Station (Cheltenham)',
#  'Upper Ferntree Gully Railway Station (Upper Ferntree Gully)',
#  'Ferntree Gully Railway Station (Ferntree Gully)',
#  'Boronia Railway Station (Boronia)',
#  'Bayswater Railway Station (Bayswater)',
#  'Heathmont Railway Station (Heathmont)',
#  'Highett Railway Station (Highett)',
#  'Glen Waverley Railway Station (Glen Waverley)',
#  'Syndal Railway Station (Glen Waverley)',
#  'Mount Waverley Railway Station (Mount Waverley)',
#  'Lilydale Railway Station (Lilydale)',
#  'Mooroolbark Railway Station (Mooroolbark)',
#  'Croydon Railway Station (Croydon)',
#  'Ringwood East Railway Station (Ringwood East)',
#  'Pakenham Railway Station (Pakenham)',
#  'Officer Railway Station (Officer)',
#  'Beaconsfield Railway Station (Beaconsfield)',
#  'Berwick Railway Station (Berwick)',
#  'Narre Warren Railway Station (Narre Warren)',
#  'Hallam Railway Station (Hallam)',
#  'Cranbourne Railway Station (Cranbourne)',
#  'Merinda Park Railway Station (Cranbourne North)',
#  'Dandenong Railway Station (Dandenong)',
#  'Yarraman Railway Station (Noble Park)',
#  'Noble Park Railway Station (Noble Park)',
#  'Sandown Park Railway Station (Springvale)',
#  'East Camberwell Railway Station (Camberwell)',
#  'Canterbury Railway Station (Canterbury)',
#  'Chatham Railway Station (Surrey Hills)',
#  'Surrey Hills Railway Station (Surrey Hills)',
#  'Mont Albert Railway Station (Mont Albert)',
#  'Laburnum Railway Station (Blackburn)',
#  'Blackburn Railway Station (Blackburn)',
#  'Nunawading Railway Station (Nunawading)',
#  'Mitcham Railway Station (Mitcham)',
#  'Heatherdale Railway Station (Ringwood)',
#  'Ringwood Railway Station (Ringwood)',
#  'Auburn Railway Station (Hawthorn East)',
#  'Glenferrie Railway Station (Hawthorn)',
#  'Hawthorn Railway Station (Hawthorn)',
#  'Burnley Railway Station (Burnley)',
#  'East Richmond Railway Station (Richmond)',
#  'Richmond Railway Station (Richmond)',
#  'Heyington Railway Station (Toorak)',
#  'Kooyong Railway Station (Kooyong)',
#  'Tooronga Railway Station (Malvern)',
#  'Gardiner Railway Station (Glen Iris)',
#  'Springvale Railway Station (Springvale)',
#  'Westall Railway Station (Clayton South)',
#  'Clayton Railway Station (Clayton)',
#  'Huntingdale Railway Station (Oakleigh)',
#  'Oakleigh Railway Station (Oakleigh)',
#  'Hughesdale Railway Station (Hughesdale)',
#  'Murrumbeena Railway Station (Murrumbeena)',
#  'Carnegie Railway Station (Carnegie)',
#  'Werribee Railway Station (Werribee)',
#  'Hoppers Crossing Railway Station (Hoppers Crossing)',
#  'Laverton Railway Station (Laverton)',
#  'Aircraft Railway Station (Laverton)',
#  'Westona Railway Station (Altona)',
#  'Altona Railway Station (Altona)',
#  'Seaholme Railway Station (Seaholme)',
#  'Westgarth Railway Station (Northcote)',
#  'Dennis Railway Station (Northcote)',
#  'Fairfield Railway Station (Fairfield)',
#  'Alphington Railway Station (Alphington)',
#  'Darebin Railway Station (Ivanhoe)',
#  'Ivanhoe Railway Station (Ivanhoe)',
#  'Eaglemont Railway Station (Eaglemont)',
#  'Heidelberg Railway Station (Heidelberg)',
#  'Rosanna Railway Station (Rosanna)',
#  'Moorabbin Railway Station (Moorabbin)',
#  'Patterson Railway Station (Bentleigh)',
#  'Bentleigh Railway Station (Bentleigh)',
#  'McKinnon Railway Station (Mckinnon)',
#  'Ormond Railway Station (Ormond)',
#  'Glenhuntly Railway Station (Glen Huntly)',
#  'Caulfield Railway Station (Caulfield East)',
#  'Malvern Railway Station (Malvern)',
#  'Armadale Railway Station (Armadale)',
#  'Toorak Railway Station (Armadale)',
#  'Hawksburn Railway Station (South Yarra)',
#  'Sandringham Railway Station (Sandringham)',
#  'Hampton Railway Station (Hampton)',
#  'Brighton Beach Railway Station (Brighton)',
#  'Middle Brighton Railway Station (Brighton)',
#  'North Brighton Railway Station (Brighton)',
#  'Gardenvale Railway Station (Brighton)',
#  'Elsternwick Railway Station (Elsternwick)',
#  'Ripponlea Railway Station (Ripponlea)',
#  'Balaclava Railway Station (Balaclava)',
#  'Windsor Railway Station (Windsor)',
#  'Prahran Railway Station (Prahran)',
#  'South Yarra Railway Station (South Yarra)',
#  'Upfield Railway Station (Coolaroo)',
#  'Gowrie Railway Station (Glenroy)',
#  'Fawkner Railway Station (Fawkner)',
#  'Merlynston Railway Station (Coburg North)',
#  'Batman Railway Station (Coburg North)',
#  'Coburg Railway Station (Coburg)',
#  'Moreland Railway Station (Coburg)',
#  'Anstey Railway Station (Brunswick)',
#  'Brunswick Railway Station (Brunswick)',
#  'Jewell Railway Station (Brunswick)']

# %%
def closest_station(row, station_df, client):
    station_list = list(station_df['geometry'])
    station_names = list(station_df['STOP_NAME'])
    locations = [row['geometry'], *station_list]  # Use row's geometry instead of rentals_df.iloc[0]

    response = client.distance_matrix(
        locations=locations,
        profile='driving-car',   
        metrics=['distance'],    
        sources=[0],             
        destinations=[i for i in (range(1, len(locations)))]  # Fix the range to match locations
    )
    
    min_index, min_distance = get_min_distance(response)
    
    return station_names[min_index],locations[min_index+1],min_distance

def get_min_distance(response):
    min_distance = math.inf
    min_index = None
    for i, distance in enumerate(response['distances'][0]):  # 'distances', not 'distance'
        if distance < min_distance:
            min_distance = distance
            min_index = i
    return min_index, min_distance  

# Apply the function to each row in rentals_df

# %%
closest_station(rentals_df.iloc[0], station_df, client)
# Out:
# ('Albion Railway Station (Sunshine North)', (144.824704, -37.777653), 2084.77)

# %%
#  testing the function
print(closest_station(rentals_df.iloc[0], station_df, client))
print(station_df[station_df['STOP_NAME'] == 'Albion Railway Station (Sunshine North)'])
# Out:
# ('Albion Railway Station (Sunshine North)', (144.824704, -37.777653), 2084.77)
#    STOP_ID   LATITUDE                                STOP_NAME   LONGITUDE  \
# 29   20004 -37.777653  Albion Railway Station (Sunshine North)  144.824704
#
#    TICKETZONE ROUTEUSSP                  geometry
# 29        1,2   Sunbury  (144.824704, -37.777653)

# %%
sample_rentals_df = rentals_df.iloc[:10].copy()
sample_rentals_df[['closest_station', 'distance(m)', 'extra_info']] = sample_rentals_df.apply(lambda x: closest_station(x, station_df, client), axis=1).apply(pd.Series)

# %%
sample_rentals_df
# Out:
#          id        price                street           suburb state  \
# 0  16889460      $420.00  27 Westmoreland Road   Sunshine North   VIC
# 1  17188457      $850.00     73 Reynard Street           Coburg   VIC
# 2  17160233    $1,300.00    35 Fairmont Avenue       Camberwell   VIC
# 3  17062496         $580      13 Vesper Avenue          Tarneit   VIC
# 4  17179442      $440.00     9 Red Robin Drive    Winter Valley   VIC
# 5  17198904         $480    50 Manna Gum Drive     Mount Duneed   VIC
# 6  17204127      $895.00      51 Ferndale Road        Glen Iris   VIC
# 7  17196019         $285       1 Cooper Street            Ouyen   VIC
# 8  17109740  $500 weekly    24 Cardamon Street  Armstrong Creek   VIC
# 9  15225888    $899/week      135 Kinnear Road        Mickleham   VIC
#
#    postcode   latitude   longitude  bedrooms  bathrooms  parking propertyType  \
# 0      3020 -37.774926  144.834817         3          1        2        house
# 1      3058 -37.748181  144.958473         3          2        0        house
# 2      3124 -37.842214  145.071069         4          2        2        house
# 3      3029 -37.835021  144.669242         4          2        2        house
# 4      3358 -37.567505  143.784207         4          2        2        house
# 5      3217 -38.226829  144.334372         3          2        2        house
# 6      3146 -37.855363  145.074779         3          1        2        house
# 7      3490 -35.068140  142.316300         2          1        3        house
# 8      3217 -38.226757  144.367373         4          2        2        house
# 9      3064 -37.534918  144.858856         4          2        2        house
#
#                      geometry                            closest_station  \
# 0  (144.8348174, -37.7749263)    Albion Railway Station (Sunshine North)
# 1  (144.9584733, -37.7481813)            Coburg Railway Station (Coburg)
# 2  (145.0710691, -37.8422139)      Hartwell Railway Station (Camberwell)
# 3   (144.6692424, -37.835021)        Werribee Railway Station (Werribee)
# 4  (143.7842071, -37.5675049)    Watergardens Railway Station (Sydenham)
# 5  (144.3343716, -38.2268287)        Werribee Railway Station (Werribee)
# 6   (145.0747789, -37.855363)      Hartwell Railway Station (Camberwell)
# 7  (142.3163004, -35.0681404)          Sunbury Railway Station (Sunbury)
# 8  (144.3673729, -38.2267566)        Werribee Railway Station (Werribee)
# 9  (144.8588556, -37.5349182)  Craigieburn Railway Station (Craigieburn)
#
#                 distance(m)  extra_info
# 0  (144.824704, -37.777653)     2084.77
# 1  (144.963336, -37.742345)     1283.48
# 2   (145.07556, -37.843985)      477.84
# 3  (144.661118, -37.899378)     8071.60
# 4   (144.77418, -37.701129)    97951.26
# 5  (144.661118, -37.899378)    58159.23
# 6   (145.07556, -37.843985)     1504.62
# 7  (144.727319, -37.579091)   405415.63
# 8  (144.661118, -37.899378)    60263.90
# 9   (144.94332, -37.601817)    14328.76

# %%
rentals_df
# Out:
#              id      price                 street          suburb state  \
# 0      16889460    $420.00   27 Westmoreland Road  Sunshine North   VIC
# 1      17188457    $850.00      73 Reynard Street          Coburg   VIC
# 2      17160233  $1,300.00     35 Fairmont Avenue      Camberwell   VIC
# 3      17062496       $580       13 Vesper Avenue         Tarneit   VIC
# 4      17179442    $440.00      9 Red Robin Drive   Winter Valley   VIC
# ...         ...        ...                    ...             ...   ...
# 15480  16644757  $1,050 pw       2/8 Skene Street    Burwood East   VIC
# 15481  16086828       $560        25 Masthead Way  Werribee South   VIC
# 15482  16076685       $700      2/26 Clyde Street  Ferntree Gully   VIC
# 15483  17174571       $835  1/40 Elizabeth Street          Coburg   VIC
# 15484  17171289     $680pw        2 Oxford Street  West Footscray   VIC
#
#        postcode   latitude   longitude  bedrooms  bathrooms  parking  \
# 0          3020 -37.774926  144.834817         3          1        2
# 1          3058 -37.748181  144.958473         3          2        0
# 2          3124 -37.842214  145.071069         4          2        2
# 3          3029 -37.835021  144.669242         4          2        2
# 4          3358 -37.567505  143.784207         4          2        2
# ...         ...        ...         ...       ...        ...      ...
# 15480      3151 -37.856688  145.132631         4          3        2
# 15481      3030 -37.963369  144.707632         4          2        2
# 15482      3156 -37.882581  145.267643         3          2        2
# 15483      3058 -37.737269  144.982527         3          3        2
# 15484      3012 -37.792359  144.877398         3          2        2
#
#             propertyType                           geometry
# 0                  house         (144.8348174, -37.7749263)
# 1                  house         (144.9584733, -37.7481813)
# 2                  house         (145.0710691, -37.8422139)
# 3                  house          (144.6692424, -37.835021)
# 4                  house         (143.7842071, -37.5675049)
# ...                  ...                                ...
# 15480          townhouse  (145.1326313, -37.85668769999999)
# 15481              house           (144.707632, -37.963369)
# 15482  apartmentUnitFlat          (145.267643, -37.8825813)
# 15483          townhouse          (144.9825267, -37.737269)
# 15484          townhouse         (144.8773982, -37.7923592)
#
# [15482 rows x 13 columns]
