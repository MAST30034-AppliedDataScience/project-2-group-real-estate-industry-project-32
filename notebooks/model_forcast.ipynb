# %%
import os
import json
import pandas as pd
from typing import Dict, Any
from urllib.request import urlretrieve
import seaborn as sns
import matplotlib.pyplot as plt
import math
import numpy as np
import pandas as pd
import geopandas as gpd
import folium
from shapely.geometry import Point
from shapely import wkt
import openrouteservice
import polars as pl
import os
from sklearn.pipeline import Pipeline
from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import OneHotEncoder
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import Lasso
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error, r2_score
from sklearn.linear_model import Ridge

# %% [markdown]
# ## Preforcast Preprocessing

# %%
df = pd.read_csv('../data/curated/forcast_dataset.csv')

# %%
df.sort_values(by=['year','month'], inplace=True)

# %%
df.value_counts(['year'], ascending=True)
# Out:
# year
# 2018        60
# 2019        97
# 2020       184
# 2021       448
# 2022       660
# 2023       955
# 2024     11977
# 2017    149572
# 2016    155236
# 2015    165369
# Name: count, dtype: int64

# %%
sum(df.isnull().sum())
# Out:
# 0

# %%
df.columns
df.drop(['longitude','latitude','Year'], axis=1, inplace=True)

# %%
df.columns
# Out:
# Index(['suburb', 'rent', 'num_bedrooms', 'num_bathrooms', 'parking',
#        'distance_to_cbd', 'nearst_train_station_dist', 'year', 'month',
#        'num_primary', 'num_secondary_public', 'num_secondary_private',
#        'num_secondary_catholic', 'num_edu_centre', 'v_high_vcaa', 'high_vcaa',
#        'good_vcaa', 'property_type_apartment / unit / flat',
#        'property_type_duplex', 'property_type_duplex-semi-detached',
#        'property_type_house', 'property_type_retirement living',
#        'property_type_serviced apartment', 'property_type_studio',
#        'property_type_townhouse', 'property_type_villa', 'lga',
#        'Rate per 100,000 population', 'lga_population'],
#       dtype='object')

# %%
suburbs  = df['suburb'].unique()

# %%
df_suburb = df['suburb'].value_counts()
df_suburb = df_suburb.reset_index()
df_suburb.columns = ['suburb','count']
could_drop = df_suburb[df_suburb['count'] < 40 ]
could_drop.sum()



# drop suburbs with less than 40 entries
df = df[~df['suburb'].isin(could_drop['suburb'])]

# %%
len(df['suburb'].unique())
# count all the unique suburbs
# Out:
# 588

# %% [markdown]
# ## Quick feature aggregation

# %%
df['avg_distance_to_cbd'] = df.groupby('suburb')['distance_to_cbd'].transform('mean')
df['avg_rent_by_suburb'] = df.groupby('suburb')['rent'].transform('mean')
df['median_rent_by_suburb'] = df.groupby('suburb')['rent'].transform('median')

#  drop the distance to cbd column, make features that uniquely identify the suburb,while still maintaining the information

df.drop('distance_to_cbd', inplace=True, axis=1)

# %%
df.columns
# Out:
# Index(['suburb', 'rent', 'num_bedrooms', 'num_bathrooms', 'parking',
#        'nearst_train_station_dist', 'year', 'month', 'num_primary',
#        'num_secondary_public', 'num_secondary_private',
#        'num_secondary_catholic', 'num_edu_centre', 'v_high_vcaa', 'high_vcaa',
#        'good_vcaa', 'property_type_apartment / unit / flat',
#        'property_type_duplex', 'property_type_duplex-semi-detached',
#        'property_type_house', 'property_type_retirement living',
#        'property_type_serviced apartment', 'property_type_studio',
#        'property_type_townhouse', 'property_type_villa', 'lga',
#        'Rate per 100,000 population', 'lga_population', 'avg_distance_to_cbd',
#        'avg_rent_by_suburb', 'median_rent_by_suburb'],
#       dtype='object')

# %%
# df['bath_bed_toghether'] = df['num_bathrooms'] + df['num_bedrooms']
# df['bath_bed_int'] =  df['num_bathrooms']*df['num_bedrooms']


# df.drop(['num_bathrooms','num_bedrooms'], axis=1, inplace=True)

# %%
# draw time series plot for rent 
df_draw = df.copy()
df_draw['date'] = pd.to_datetime(df[['year', 'month']].assign(day=1))
df_draw.set_index('date', inplace=True)
df_draw.drop(['year', 'month'], axis=1, inplace=True)
# the plot shows that the rent is not stationary, it has is increasing over time

df_draw_plot = df_draw.groupby('date')['rent'].mean()
df_draw_plot.plot()
# Out:
# <Axes: xlabel='date'>

# %% [markdown]
# ### Minor Preprocessing

# %%
# the makeing the training(rentals before 2022) and the test set(after 2022)
df_reg = df.copy()
df_reg_sub = df_reg[['suburb']]
df_reg.drop(['suburb'], axis=1, inplace=True)
df_reg.drop(['lga'],axis=1, inplace=True)

X = df_reg.drop('rent', axis=1)
y = df_reg['rent']

X_train = X.loc[df_reg['year'] < 2022]
X_test = X.loc[df_reg['year'] >= 2022]
y_train = y.loc[df_reg['year'] < 2022]
y_test = y.loc[df_reg['year'] >= 2022]

df_reg_sub_train = df_reg_sub.loc[df_reg['year'] < 2022]
df_reg_sub_test = df_reg_sub.loc[df_reg['year'] >= 2022]

# y_test = np.log(y_test)
# y_train = np.log(y_train)

# %%
df['suburb']
# Out:
# 2351               corio
# 3910            seabrook
# 18848          southbank
# 20349             ormond
# 22522           hawthorn
#                ...
# 484542          box hill
# 484546           tarneit
# 484547         glen iris
# 484548    gladstone park
# 484550        shepparton
# Name: suburb, Length: 478412, dtype: object

# %% [markdown]
# # Dummy model

# %%
from sklearn.dummy import DummyRegressor

dummy_model = DummyRegressor(strategy="mean") 
dummy_model.fit(X_train, y_train) 

y_dummy_pred = dummy_model.predict(X_test)

dummy_mse = mean_squared_error(y_test, y_dummy_pred)
dummy_r2 = r2_score(y_test, y_dummy_pred)

print(f'Dummy Model Mean Squared Error: {dummy_mse}')
print(f'Dummy Model R2 Score: {dummy_r2}')

# the dummy model used as a baseline model
# Out:
# Dummy Model Mean Squared Error: 111837.54464681353
# Dummy Model R2 Score: -0.5619581150181188

# %% [markdown]
# ## Training and testing linear regression per property basis

# %%
plt.hist(np.log(y), bins=50)
# to test the assumption of normality of the target variable
# Out:
# (array([2.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00, 2.0000e+00,
#         0.0000e+00, 1.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00,
#         0.0000e+00, 0.0000e+00, 0.0000e+00, 3.0000e+00, 1.0000e+00,
#         0.0000e+00, 0.0000e+00, 0.0000e+00, 1.0000e+00, 1.0000e+00,
#         1.0000e+00, 2.0000e+00, 5.0000e+00, 3.0000e+01, 2.1000e+01,
#         1.0000e+01, 7.0000e+00, 3.3000e+01, 1.4600e+02, 4.1400e+02,
#         1.5490e+03, 4.0660e+03, 1.0579e+04, 2.9248e+04, 6.6888e+04,
#         1.1983e+05, 9.8742e+04, 5.6538e+04, 4.0293e+04, 2.1112e+04,
#         1.3285e+04, 7.1710e+03, 3.5240e+03, 2.1640e+03, 1.3530e+03,
#         7.9000e+02, 2.4300e+02, 2.3700e+02, 8.1000e+01, 3.9000e+01]),
#  array([0.        , 0.16537464, 0.33074927, 0.49612391, 0.66149855,
#         0.82687318, 0.99224782, 1.15762246, 1.32299709, 1.48837173,
#         1.65374637, 1.819121  , 1.98449564, 2.14987028, 2.31524491,
#         2.48061955, 2.64599419, 2.81136882, 2.97674346, 3.1421181 ,
#         3.30749273, 3.47286737, 3.63824201, 3.80361664, 3.96899128,
#         4.13436592, 4.29974055, 4.46511519, 4.63048983, 4.79586446,
#         4.9612391 , 5.12661374, 5.29198837, 5.45736301, 5.62273765,
#         5.78811228, 5.95348692, 6.11886156, 6.28423619, 6.44961083,
#         6.61498547, 6.7803601 , 6.94573474, 7.11110938, 7.27648401,
#         7.44185865, 7.60723329, 7.77260792, 7.93798256, 8.1033572 ,
#         8.26873183]),
#  <BarContainer object of 50 artists>)

# %%
plt.hist((y), bins=100)
# Out:
# (array([1.4000e+01, 6.7000e+01, 9.6000e+01, 1.2080e+03, 4.9050e+03,
#         1.0584e+04, 2.6625e+04, 4.8658e+04, 7.9580e+04, 7.1760e+04,
#         5.2461e+04, 4.4012e+04, 3.3510e+04, 1.7725e+04, 2.1034e+04,
#         1.3521e+04, 1.1327e+04, 9.1220e+03, 3.0280e+03, 5.4280e+03,
#         3.5800e+03, 3.4580e+03, 1.9030e+03, 2.1160e+03, 1.8720e+03,
#         1.7990e+03, 1.0400e+03, 3.9800e+02, 1.0370e+03, 3.7600e+02,
#         1.0930e+03, 1.9300e+02, 5.1900e+02, 7.9600e+02, 3.5300e+02,
#         4.3000e+02, 4.1000e+01, 1.3800e+02, 5.4600e+02, 1.0900e+02,
#         5.9000e+01, 2.0800e+02, 1.3100e+02, 1.6700e+02, 1.2500e+02,
#         1.1000e+01, 1.9900e+02, 7.2000e+01, 8.1000e+01, 5.9000e+01,
#         1.6000e+01, 2.2300e+02, 1.0000e+01, 4.5000e+01, 5.0000e+00,
#         2.1000e+01, 9.0000e+01, 2.7000e+01, 3.2000e+01, 3.0000e+00,
#         9.0000e+00, 3.3000e+01, 7.0000e+00, 8.0000e+00, 1.0400e+02,
#         3.0000e+00, 2.3000e+01, 7.0000e+00, 1.0000e+00, 1.2000e+01,
#         1.9000e+01, 2.0000e+01, 2.0000e+00, 2.0000e+00, 1.1000e+01,
#         4.0000e+00, 3.2000e+01, 1.0000e+00, 1.0000e+00, 3.0000e+00,
#         3.0000e+00, 1.0000e+00, 1.0000e+01, 7.0000e+00, 4.0000e+00,
#         1.0000e+00, 1.0000e+00, 3.0000e+00, 2.0000e+00, 2.2000e+01,
#         0.0000e+00, 0.0000e+00, 1.0000e+00, 1.0000e+00, 2.0000e+00,
#         0.0000e+00, 1.0000e+00, 3.0000e+00, 1.0000e+00, 1.0000e+00]),
#  array([1.00000e+00, 3.99900e+01, 7.89800e+01, 1.17970e+02, 1.56960e+02,
#         1.95950e+02, 2.34940e+02, 2.73930e+02, 3.12920e+02, 3.51910e+02,
#         3.90900e+02, 4.29890e+02, 4.68880e+02, 5.07870e+02, 5.46860e+02,
#         5.85850e+02, 6.24840e+02, 6.63830e+02, 7.02820e+02, 7.41810e+02,
#         7.80800e+02, 8.19790e+02, 8.58780e+02, 8.97770e+02, 9.36760e+02,
#         9.75750e+02, 1.01474e+03, 1.05373e+03, 1.09272e+03, 1.13171e+03,
#         1.17070e+03, 1.20969e+03, 1.24868e+03, 1.28767e+03, 1.32666e+03,
#         1.36565e+03, 1.40464e+03, 1.44363e+03, 1.48262e+03, 1.52161e+03,
#         1.56060e+03, 1.59959e+03, 1.63858e+03, 1.67757e+03, 1.71656e+03,
#         1.75555e+03, 1.79454e+03, 1.83353e+03, 1.87252e+03, 1.91151e+03,
#         1.95050e+03, 1.98949e+03, 2.02848e+03, 2.06747e+03, 2.10646e+03,
#         2.14545e+03, 2.18444e+03, 2.22343e+03, 2.26242e+03, 2.30141e+03,
#         2.34040e+03, 2.37939e+03, 2.41838e+03, 2.45737e+03, 2.49636e+03,
#         2.53535e+03, 2.57434e+03, 2.61333e+03, 2.65232e+03, 2.69131e+03,
#         2.73030e+03, 2.76929e+03, 2.80828e+03, 2.84727e+03, 2.88626e+03,
#         2.92525e+03, 2.96424e+03, 3.00323e+03, 3.04222e+03, 3.08121e+03,
#         3.12020e+03, 3.15919e+03, 3.19818e+03, 3.23717e+03, 3.27616e+03,
#         3.31515e+03, 3.35414e+03, 3.39313e+03, 3.43212e+03, 3.47111e+03,
#         3.51010e+03, 3.54909e+03, 3.58808e+03, 3.62707e+03, 3.66606e+03,
#         3.70505e+03, 3.74404e+03, 3.78303e+03, 3.82202e+03, 3.86101e+03,
#         3.90000e+03]),
#  <BarContainer object of 100 artists>)

# %%
X_train.columns
# X_train['lga']
# Out:
# Index(['num_bedrooms', 'num_bathrooms', 'parking', 'nearst_train_station_dist',
#        'year', 'month', 'num_primary', 'num_secondary_public',
#        'num_secondary_private', 'num_secondary_catholic', 'num_edu_centre',
#        'v_high_vcaa', 'high_vcaa', 'good_vcaa',
#        'property_type_apartment / unit / flat', 'property_type_duplex',
#        'property_type_duplex-semi-detached', 'property_type_house',
#        'property_type_retirement living', 'property_type_serviced apartment',
#        'property_type_studio', 'property_type_townhouse',
#        'property_type_villa', 'Rate per 100,000 population', 'lga_population',
#        'avg_distance_to_cbd', 'avg_rent_by_suburb', 'median_rent_by_suburb'],
#       dtype='object')

# %%
# linear regression model

lin_model = LinearRegression()
lin_model.fit(X_train, y_train)

y_pred = lin_model.predict(X_test)


mse = mean_squared_error(y_test, y_pred)
r2 = r2_score(y_test, y_pred)


#  find the mse and r2 score of the linear regression model
print(f'Mean Squared Error: {mse}')
print(f'R2 Score: {r2}')

#  the actual vs predicted rent prices
plt.figure(figsize=(10, 6))
sns.lineplot(x=pd.to_datetime(X_test[['year', 'month']].assign(day=1)).values, y=y_test, label='Actual Rent', color='blue')
sns.lineplot(x=pd.to_datetime(X_test[['year', 'month']].assign(day=1)).values, y=y_pred, label='Predicted Rent', color='red')
plt.title('Actual vs Predicted Rent Prices')
plt.xlabel('Date')
plt.ylabel('Rent')
plt.legend()
plt.show()
# Out:
# Mean Squared Error: 42157.77328582746
# R2 Score: 0.4112113574842471

# %%
rent1 = y_test.rename('rent1')

result = pd.concat([rent1.reset_index(drop=True), pd.Series(y_pred, name='predicted_rent').reset_index(drop=True), X_test.reset_index(drop=True),y_test.reset_index(drop=True),df_reg_sub_test.reset_index(drop=True)], axis=1)
print(result.head())
# Out:
#    rent1  predicted_rent  num_bedrooms  num_bathrooms  parking  \
# 0  510.0      379.990755           3.0            1.0      2.0
# 1  460.0      378.845671           2.0            1.0      1.0
# 2  720.0      599.746226           3.0            2.0      4.0
# 3  610.0      533.817074           4.0            2.0      2.0
# 4  550.0      537.943005           2.0            1.0      0.0
#
#    nearst_train_station_dist  year  month  num_primary  num_secondary_public  \
# 0                   0.323394  2022      1            8                     3
# 1                   0.308021  2022      1            7                     2
# 2                   0.302302  2022      1            5                     1
# 3                   4.479085  2022      1            6                     2
# 4                   1.582158  2022      1            4                     0
#
#    ...  property_type_studio  property_type_townhouse  property_type_villa  \
# 0  ...                 False                    False                False
# 1  ...                 False                    False                False
# 2  ...                 False                    False                False
# 3  ...                 False                    False                False
# 4  ...                 False                    False                False
#
#    Rate per 100,000 population  lga_population  avg_distance_to_cbd  \
# 0                  6827.499585        253182.0            25.477583
# 1                  8326.416786        150605.0            11.856672
# 2                  6064.069653        160107.0            18.792523
# 3                  5270.557664        309398.0            21.364494
# 4                 11578.735014        104096.0             5.870357
#
#    avg_rent_by_suburb  median_rent_by_suburb   rent       suburb
# 0          370.202647                  360.0  510.0  craigieburn
# 1          368.786441                  350.0  460.0    reservoir
# 2          458.420495                  430.0  720.0   cheltenham
# 3          388.469280                  370.0  610.0    truganina
# 4          515.213144                  450.0  550.0     st kilda
#
# [5 rows x 32 columns]

# %%
result[['rent','rent1']]
# Out:
#          rent   rent1
# 0       510.0   510.0
# 1       460.0   460.0
# 2       720.0   720.0
# 3       610.0   610.0
# 4       550.0   550.0
# ...       ...     ...
# 13115   620.0   620.0
# 13116   580.0   580.0
# 13117  1095.0  1095.0
# 13118   720.0   720.0
# 13119   550.0   550.0
#
# [13120 rows x 2 columns]

# %%
result[result['suburb'] == 'abbotsford']
# Out:
#         rent1  predicted_rent  num_bedrooms  num_bathrooms  parking  \
# 1369    915.0      723.086038           3.0            2.0      1.0
# 1607    780.0      708.011401           3.0            2.0      2.0
# 1779   1800.0      865.019182           4.0            3.0      2.0
# 1860    900.0      640.940475           2.0            2.0      1.0
# 2066    800.0      641.876836           2.0            2.0      1.0
# ...       ...             ...           ...            ...      ...
# 12413   430.0      499.059053           1.0            1.0      1.0
# 12491   480.0      489.749504           1.0            1.0      0.0
# 12620   580.0      558.393840           2.0            1.0      1.0
# 12668   520.0      490.069149           1.0            1.0      0.0
# 12953   680.0      571.009135           2.0            1.0      1.0
#
#        nearst_train_station_dist  year  month  num_primary  \
# 1369                    0.299541  2023      9            2
# 1607                    1.383839  2024      1            2
# 1779                    0.741504  2024      3            2
# 1860                    1.356315  2024      4            2
# 2066                    1.495632  2024      5            2
# ...                          ...   ...    ...          ...
# 12413                   0.581582  2024      9            2
# 12491                   1.356315  2024      9            2
# 12620                   1.263224  2024      9            2
# 12668                   1.495632  2024      9            2
# 12953                   0.633269  2024      9            2
#
#        num_secondary_public  ...  property_type_studio  \
# 1369                      0  ...                 False
# 1607                      0  ...                 False
# 1779                      0  ...                 False
# 1860                      0  ...                 False
# 2066                      0  ...                 False
# ...                     ...  ...                   ...
# 12413                     0  ...                 False
# 12491                     0  ...                 False
# 12620                     0  ...                 False
# 12668                     0  ...                 False
# 12953                     0  ...                 False
#
#        property_type_townhouse  property_type_villa  \
# 1369                      True                False
# 1607                     False                False
# 1779                     False                False
# 1860                     False                False
# 2066                     False                False
# ...                        ...                  ...
# 12413                    False                False
# 12491                    False                False
# 12620                    False                False
# 12668                    False                False
# 12953                    False                False
#
#        Rate per 100,000 population  lga_population  avg_distance_to_cbd  \
# 1369                  12913.553895    97448.000000             4.026649
# 1607                  13543.603693    97727.776726             4.026649
# 1779                  13543.603693    97727.776726             4.026649
# 1860                  13543.603693    97727.776726             4.026649
# 2066                  13543.603693    97727.776726             4.026649
# ...                            ...             ...                  ...
# 12413                 13543.603693    97727.776726             4.026649
# 12491                 13543.603693    97727.776726             4.026649
# 12620                 13543.603693    97727.776726             4.026649
# 12668                 13543.603693    97727.776726             4.026649
# 12953                 13543.603693    97727.776726             4.026649
#
#        avg_rent_by_suburb  median_rent_by_suburb    rent      suburb
# 1369           505.134401                  480.0   915.0  abbotsford
# 1607           505.134401                  480.0   780.0  abbotsford
# 1779           505.134401                  480.0  1800.0  abbotsford
# 1860           505.134401                  480.0   900.0  abbotsford
# 2066           505.134401                  480.0   800.0  abbotsford
# ...                   ...                    ...     ...         ...
# 12413          505.134401                  480.0   430.0  abbotsford
# 12491          505.134401                  480.0   480.0  abbotsford
# 12620          505.134401                  480.0   580.0  abbotsford
# 12668          505.134401                  480.0   520.0  abbotsford
# 12953          505.134401                  480.0   680.0  abbotsford
#
# [61 rows x 32 columns]

# %% [markdown]
# ## Train and test the ridge regression model

# %% [markdown]
# ### evaluate the rankings for features

# %%
# the ridge regression model, the alpha value is set to 1 to prevent overfitting

ridge_model = Ridge(alpha=1)
ridge_model.fit(X_train, y_train)

y_pred = ridge_model.predict(X_test)

mse = mean_squared_error(y_test, y_pred)
r2 = r2_score(y_test, y_pred)

print(f'Mean Squared Error: {mse}')
print(f'R2 Score: {r2}')


# find the most significant features, the coefficients of the features
coefficients = pd.DataFrame(ridge_model.coef_, index=X_train.columns, columns=['Coefficient'])
coefficients['Absolute Coefficient'] = coefficients['Coefficient'].abs()
coefficients = coefficients.sort_values(by='Absolute Coefficient', ascending=False)
print(coefficients)

# the actual vs predicted rent prices(average rent prices)
plt.figure(figsize=(10, 6))
sns.lineplot(x=pd.to_datetime(X_test[['year', 'month']].assign(day=1)).values, y=y_test, label='Actual Rent', color='blue')
sns.lineplot(x=pd.to_datetime(X_test[['year', 'month']].assign(day=1)).values, y=y_pred, label='Predicted Rent', color='red')
plt.title('Actual vs Predicted Rent Prices')
plt.xlabel('Date')
plt.ylabel('Rent')
plt.legend()
plt.show()
# Out:
# Mean Squared Error: 42157.704876096075
# R2 Score: 0.4112123129159442
#                                        Coefficient  Absolute Coefficient
# num_bathrooms                            85.416017             85.416017
# property_type_studio                     84.338331             84.338331
# num_bedrooms                             57.770202             57.770202
# property_type_apartment / unit / flat   -43.836848             43.836848
# property_type_villa                     -43.066717             43.066717
# property_type_house                     -29.775093             29.775093
# property_type_retirement living          27.457801             27.457801
# property_type_serviced apartment         15.678789             15.678789
# year                                     13.432809             13.432809
# parking                                  11.087126             11.087126
# num_edu_centre                           10.739293             10.739293
# good_vcaa                                 9.253270              9.253270
# v_high_vcaa                               8.449885              8.449885
# property_type_duplex-semi-detached       -6.261567              6.261567
# num_secondary_public                     -5.157043              5.157043
# high_vcaa                                -4.865779              4.865779
# property_type_townhouse                  -4.534695              4.534695
# num_secondary_catholic                   -3.906104              3.906104
# avg_distance_to_cbd                      -2.427299              2.427299
# num_primary                              -2.351285              2.351285
# nearst_train_station_dist                 2.294386              2.294386
# num_secondary_private                    -2.189371              2.189371
# avg_rent_by_suburb                        1.340370              1.340370
# median_rent_by_suburb                    -0.642911              0.642911
# month                                     0.616714              0.616714
# Rate per 100,000 population               0.003506              0.003506
# lga_population                           -0.000202              0.000202
# property_type_duplex                      0.000000              0.000000

# %% [markdown]
# ##

# %% [markdown]
# ## Train and Test the Random forrest and find the important features

# %%
from sklearn.ensemble import RandomForestRegressor

# the random forest model   

rf_model = RandomForestRegressor(n_estimators=100, random_state=42)
rf_model.fit(X_train, y_train)

y_pred = rf_model.predict(X_test)

mse = mean_squared_error(y_test, y_pred)
r2 = r2_score(y_test, y_pred)

print(f'Mean Squared Error: {mse}')
print(f'R2 Score: {r2}')


# find the most significant features
importances = rf_model.feature_importances_
indices = np.argsort(importances)[::-1]
features = X_train.columns

print("Feature ranking:")
for f in range(X_train.shape[1]):
    print(f"{f + 1}. feature {features[indices[f]]} ({importances[indices[f]]})")

plt.figure(figsize=(10, 6))
plt.title("Feature importances")
plt.bar(range(X_train.shape[1]), importances[indices], align="center")
plt.xticks(range(X_train.shape[1]), features[indices], rotation=90)
plt.xlim([-1, X_train.shape[1]])
plt.show()

plt.figure(figsize=(10, 6))
sns.lineplot(x=pd.to_datetime(X_test[['year', 'month']].assign(day=1)).values, y=y_test, label='Actual Rent', color='blue')
sns.lineplot(x=pd.to_datetime(X_test[['year', 'month']].assign(day=1)).values, y=y_pred, label='Predicted Rent', color='red')
plt.title('Actual vs Predicted Rent Prices')
plt.xlabel('Date')
plt.ylabel('Rent')
plt.legend()
plt.show()
# Out:
# Mean Squared Error: 40480.35269041298
# R2 Score: 0.4346387379724399
# Feature ranking:
# 1. feature avg_rent_by_suburb (0.32043680606264585)
# 2. feature num_bathrooms (0.20401970066991562)
# 3. feature nearst_train_station_dist (0.15575582426092885)
# 4. feature num_bedrooms (0.08566787633292805)
# 5. feature avg_distance_to_cbd (0.0503912961262393)
# 6. feature month (0.04359082276911154)
# 7. feature lga_population (0.026870360070574268)
# 8. feature parking (0.02295245194226727)
# 9. feature median_rent_by_suburb (0.02162061528215492)
# 10. feature Rate per 100,000 population (0.018248849801645636)
# 11. feature year (0.009836299314227425)
# 12. feature property_type_apartment / unit / flat (0.00642968722705862)
# 13. feature num_primary (0.004966938175309064)
# 14. feature property_type_house (0.004910762602089911)
# 15. feature property_type_townhouse (0.0041032012948253975)
# 16. feature v_high_vcaa (0.0040220408173066435)
# 17. feature num_secondary_private (0.003548192489639966)
# 18. feature num_secondary_public (0.0027992043588242845)
# 19. feature property_type_studio (0.0026006736867902696)
# 20. feature num_secondary_catholic (0.0019450197334526804)
# 21. feature good_vcaa (0.001894677574502906)
# 22. feature num_edu_centre (0.0017739029494928684)
# 23. feature high_vcaa (0.0011059089045968918)
# 24. feature property_type_serviced apartment (0.0002205385816669052)
# 25. feature property_type_villa (0.00015768729891185064)
# 26. feature property_type_duplex-semi-detached (0.00012784491836371437)
# 27. feature property_type_retirement living (2.81675452939225e-06)
# 28. feature property_type_duplex (0.0)

# %% [markdown]
# ## Train and Test the XGboost and find the important features

# %%
from xgboost import XGBRegressor
from sklearn.metrics import mean_squared_error, r2_score
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
import pandas as pd

# Initialize the XGBRegressor
xgb_model = XGBRegressor(n_estimators=200, random_state=42, reg_alpha=0.1, reg_lambda=1.0)

# Train the model
xgb_model.fit(X_train, y_train)

y_pred = xgb_model.predict(X_test)

mse = mean_squared_error(y_test, y_pred)
r2 = r2_score(y_test, y_pred)

print(f'Mean Squared Error: {mse}')
print(f'R2 Score: {r2}')

importances = xgb_model.feature_importances_
indices = np.argsort(importances)[::-1]
features = X_train.columns

# Display feature ranking
print("Feature ranking:")
for f in range(X_train.shape[1]):
    print(f"{f + 1}. feature {features[indices[f]]} ({importances[indices[f]]})")

# Plot feature importances
plt.figure(figsize=(10, 6))
plt.title("Feature importances")
plt.bar(range(X_train.shape[1]), importances[indices], align="center")
plt.xticks(range(X_train.shape[1]), features[indices], rotation=90)
plt.xlim([-1, X_train.shape[1]])
plt.show()

# Plot actual vs predicted rent prices
plt.figure(figsize=(10, 6))
sns.lineplot(x=pd.to_datetime(X_test[['year', 'month']].assign(day=1)).values, y=y_test, label='Actual Rent', color='blue')
sns.lineplot(x=pd.to_datetime(X_test[['year', 'month']].assign(day=1)).values, y=y_pred, label='Predicted Rent', color='red')
plt.title('Actual vs Predicted Rent Prices')
plt.xlabel('Date')
plt.ylabel('Rent')
plt.legend()
plt.show()
# Out:
# Mean Squared Error: 28118.35811248478
# R2 Score: 0.6072902192776055
# Feature ranking:
# 1. feature avg_rent_by_suburb (0.33714067935943604)
# 2. feature num_bathrooms (0.1790117621421814)
# 3. feature num_bedrooms (0.06001481041312218)
# 4. feature avg_distance_to_cbd (0.05814068391919136)
# 5. feature property_type_apartment / unit / flat (0.04200300574302673)
# 6. feature num_secondary_catholic (0.03633327782154083)
# 7. feature median_rent_by_suburb (0.031181754544377327)
# 8. feature v_high_vcaa (0.030589932575821877)
# 9. feature property_type_studio (0.025097914040088654)
# 10. feature property_type_house (0.022217368707060814)
# 11. feature lga_population (0.020999986678361893)
# 12. feature num_secondary_private (0.020696502178907394)
# 13. feature high_vcaa (0.015768006443977356)
# 14. feature nearst_train_station_dist (0.015516501851379871)
# 15. feature parking (0.015102602541446686)
# 16. feature Rate per 100,000 population (0.01500758621841669)
# 17. feature year (0.014024345204234123)
# 18. feature num_edu_centre (0.010113839991390705)
# 19. feature num_primary (0.009759371168911457)
# 20. feature num_secondary_public (0.00895756483078003)
# 21. feature property_type_townhouse (0.008300583809614182)
# 22. feature good_vcaa (0.007888449355959892)
# 23. feature month (0.005359247326850891)
# 24. feature property_type_villa (0.004692502785474062)
# 25. feature property_type_serviced apartment (0.0030620819889009)
# 26. feature property_type_duplex-semi-detached (0.0028378090355545282)
# 27. feature property_type_retirement living (0.00018179864855483174)
# 28. feature property_type_duplex (0.0)

# %% [markdown]
# ## Preparing data to forcast

# %%
lga_pop = pd.read_csv('../data/curated/lga_pop.csv')
crime_df = pd.read_csv('../data/curated/crime_by_lga.csv')

# %%
crime_df
# Out:
#       Unnamed: 0 Local Government Area  Year  Rate per 100,000 population
# 0              0                alpine  2015                  3572.290611
# 1              1                alpine  2016                  3378.915567
# 2              2                alpine  2017                  2987.309845
# 3              3                alpine  2018                  3899.547652
# 4              4                alpine  2019                  4657.470552
# ...          ...                   ...   ...                          ...
# 1022         788          yarriambiack  2023                  7168.570981
# 1023         789          yarriambiack  2024                  8609.398034
# 1024         868          yarriambiack  2025                  8391.308656
# 1025         947          yarriambiack  2026                  8525.497956
# 1026        1026          yarriambiack  2027                  8442.931953
#
# [1027 rows x 4 columns]

# %%
crime_df.drop('Unnamed: 0', axis=1, inplace=True)
crime_df.rename(columns={'Local Government Area':'lga','Year':'year'}, inplace=True)

#  different dataframes for different years to predict for the future

crime_df_2025 = crime_df[crime_df['year'] == 2025]
crime_df_2025 = crime_df_2025.drop('year', axis=1)

crime_df_2026 = crime_df[crime_df['year'] == 2026]
crime_df_2026 = crime_df_2026.drop('year', axis=1)

crime_df_2027 = crime_df[crime_df['year'] == 2027]
crime_df_2027 = crime_df_2027.drop('year', axis=1)

# %%
# different dataframes for different years to predict for the future
lga_pop_2025 = lga_pop[lga_pop['year'] == 2025] 
lga_pop_2025 = lga_pop_2025.drop('year', axis=1)


lga_pop_2026 = lga_pop[lga_pop['year'] == 2026]
lga_pop_2026 = lga_pop_2026.drop('year', axis=1)


lga_pop_2027 = lga_pop[lga_pop['year'] == 2027]
lga_pop_2027 = lga_pop_2027.drop('year', axis=1)

# %%
df.columns
# Out:
# Index(['suburb', 'rent', 'num_bedrooms', 'num_bathrooms', 'parking',
#        'nearst_train_station_dist', 'year', 'month', 'num_primary',
#        'num_secondary_public', 'num_secondary_private',
#        'num_secondary_catholic', 'num_edu_centre', 'v_high_vcaa', 'high_vcaa',
#        'good_vcaa', 'property_type_apartment / unit / flat',
#        'property_type_duplex', 'property_type_duplex-semi-detached',
#        'property_type_house', 'property_type_retirement living',
#        'property_type_serviced apartment', 'property_type_studio',
#        'property_type_townhouse', 'property_type_villa', 'lga',
#        'Rate per 100,000 population', 'lga_population', 'avg_distance_to_cbd',
#        'avg_rent_by_suburb', 'median_rent_by_suburb'],
#       dtype='object')

# %%
df_forcast = df.copy()


# df_reg_sub = df_forcast['suburb']
# df.drop(['suburb'], axis=1, inplace=True)



# df_reg.drop(['lga'], axis=1, inplace=True)

X_train = df.drop('rent', axis=1)
X_train.drop(['lga',"suburb"], axis=1, inplace=True)

y_train = df['rent']


#  the merged dataframes for the different years to predict for the future valeus
#  since we know the values of the features for the future years(via forcasting )

df_forcast_2025 = df.copy()
df_forcast_2025['year'] = 2025

X_forcast_2025 = df_forcast_2025.drop(["lga_population","Rate per 100,000 population"], axis=1)
X_forcast_2025 = pd.merge(X_forcast_2025, lga_pop_2025, on='lga', how='left')
X_forcast_2025 = pd.merge(X_forcast_2025, crime_df_2025, on='lga', how='left')
X_2025_suburb = X_forcast_2025['suburb']
X_2025_rent = df_forcast_2025['rent']

X_forcast_2025.drop(['lga','suburb','rent'], axis=1, inplace=True)

# ----------------------------

df_forcast_2026 = df.copy()
df_forcast_2026['year'] = 2026

X_forcast_2026 = df_forcast_2026.drop(["lga_population","Rate per 100,000 population"], axis=1)
X_forcast_2026 = pd.merge(X_forcast_2026, lga_pop_2026, on='lga', how='left')
X_forcast_2026 = pd.merge(X_forcast_2026, crime_df_2026, on='lga', how='left')
X_2026_suburb = X_forcast_2026['suburb']
X_2026_rent = df_forcast_2026['rent']


X_forcast_2026.drop(['lga','suburb','rent'], axis=1, inplace=True)

#  ----------------------------

df_forcast_2027 = df.copy()
df_forcast_2027['year'] = 2027

X_forcast_2027 = df_forcast_2027.drop(["lga_population","Rate per 100,000 population"], axis=1)
X_forcast_2027 = pd.merge(X_forcast_2027, lga_pop_2027, on='lga', how='left')
X_forcast_2027 = pd.merge(X_forcast_2027, crime_df_2027, on='lga', how='left')
X_2027_suburb = X_forcast_2027['suburb']
X_2027_rent = df_forcast_2027['rent']


X_forcast_2027.drop(['lga','suburb','rent'], axis=1, inplace=True)

# %%
X_train
# Out:
#         num_bedrooms  num_bathrooms  parking  nearst_train_station_dist  year  \
# 2351             3.0            1.0      1.0                  33.970773  2015
# 3910             2.0            1.0      1.0                   1.535148  2015
# 18848            2.0            2.0      1.0                   1.101459  2015
# 20349            2.0            2.0      1.0                   0.264072  2015
# 22522            2.0            1.0      1.0                   0.923387  2015
# ...              ...            ...      ...                        ...   ...
# 484542           2.0            2.0      1.0                   0.641664  2024
# 484546           4.0            2.0      2.0                   7.170467  2024
# 484547           4.0            3.0      3.0                   0.867788  2024
# 484548           4.0            3.0      1.0                   1.485309  2024
# 484550           4.0            1.0      1.0                 136.420636  2024
#
#         month  num_primary  num_secondary_public  num_secondary_private  \
# 2351        1            3                     1                      1
# 3910        1            1                     0                      0
# 18848       1            1                     1                      0
# 20349       1            4                     0                      2
# 22522       1            6                     1                      2
# ...       ...          ...                   ...                    ...
# 484542      9            2                     1                      1
# 484546      9            9                     2                      2
# 484547      9            6                     0                      1
# 484548      9            3                     1                      0
# 484550      9            8                     1                      3
#
#         num_secondary_catholic  ...  property_type_retirement living  \
# 2351                         0  ...                            False
# 3910                         0  ...                            False
# 18848                        0  ...                            False
# 20349                        0  ...                            False
# 22522                        0  ...                            False
# ...                        ...  ...                              ...
# 484542                       1  ...                            False
# 484546                       1  ...                            False
# 484547                       1  ...                            False
# 484548                       0  ...                            False
# 484550                       1  ...                            False
#
#         property_type_serviced apartment  property_type_studio  \
# 2351                               False                 False
# 3910                               False                 False
# 18848                              False                 False
# 20349                              False                 False
# 22522                              False                 False
# ...                                  ...                   ...
# 484542                             False                 False
# 484546                             False                 False
# 484547                             False                 False
# 484548                             False                 False
# 484550                             False                 False
#
#         property_type_townhouse  property_type_villa  \
# 2351                      False                False
# 3910                      False                False
# 18848                     False                False
# 20349                     False                False
# 22522                     False                False
# ...                         ...                  ...
# 484542                    False                False
# 484546                    False                False
# 484547                    False                False
# 484548                     True                False
# 484550                    False                False
#
#         Rate per 100,000 population  lga_population  avg_distance_to_cbd  \
# 2351                    8223.212522   232926.000000            60.414872
# 3910                    7389.227044    91674.000000            19.484784
# 18848                  25240.370565   136872.000000             1.314855
# 20349                   3965.763000   145924.000000            12.171181
# 22522                   3767.031181   174753.000000             6.294578
# ...                             ...             ...                  ...
# 484542                  5698.885766   179469.707553            14.217259
# 484546                  5985.753865   337384.401708            25.782024
# 484547                  9917.831843   111445.270259             9.512496
# 484548                  7444.876870   270240.488598            14.994288
# 484550                 12677.280803    69503.823268           164.323123
#
#         avg_rent_by_suburb  median_rent_by_suburb
# 2351            270.375717                  270.0
# 3910            368.674419                  360.0
# 18848           674.013677                  600.0
# 20349           441.264183                  390.0
# 22522           490.883340                  420.0
# ...                    ...                    ...
# 484542          449.932146                  430.0
# 484546          372.621287                  360.0
# 484547          547.427076                  453.0
# 484548          381.800623                  370.0
# 484550          294.082756                  285.0
#
# [478412 rows x 28 columns]

# %%
len(X_forcast_2025.columns)
# Out:
# 28

# %% [markdown]
# ## Forcasting using XGboost

# %%
X_train.columns
# Out:
# Index(['num_bedrooms', 'num_bathrooms', 'parking', 'nearst_train_station_dist',
#        'year', 'month', 'num_primary', 'num_secondary_public',
#        'num_secondary_private', 'num_secondary_catholic', 'num_edu_centre',
#        'v_high_vcaa', 'high_vcaa', 'good_vcaa',
#        'property_type_apartment / unit / flat', 'property_type_duplex',
#        'property_type_duplex-semi-detached', 'property_type_house',
#        'property_type_retirement living', 'property_type_serviced apartment',
#        'property_type_studio', 'property_type_townhouse',
#        'property_type_villa', 'Rate per 100,000 population', 'lga_population',
#        'avg_distance_to_cbd', 'avg_rent_by_suburb', 'median_rent_by_suburb'],
#       dtype='object')

# %%
X_forcast_2025.columns
# Out:
# Index(['num_bedrooms', 'num_bathrooms', 'parking', 'nearst_train_station_dist',
#        'year', 'month', 'num_primary', 'num_secondary_public',
#        'num_secondary_private', 'num_secondary_catholic', 'num_edu_centre',
#        'v_high_vcaa', 'high_vcaa', 'good_vcaa',
#        'property_type_apartment / unit / flat', 'property_type_duplex',
#        'property_type_duplex-semi-detached', 'property_type_house',
#        'property_type_retirement living', 'property_type_serviced apartment',
#        'property_type_studio', 'property_type_townhouse',
#        'property_type_villa', 'avg_distance_to_cbd', 'avg_rent_by_suburb',
#        'median_rent_by_suburb', 'lga_population',
#        'Rate per 100,000 population'],
#       dtype='object')

# %%
X_forcast_2025 = X_forcast_2025[X_train.columns]
X_forcast_2026 = X_forcast_2026[X_train.columns]
X_forcast_2027 = X_forcast_2027[X_train.columns]

# %%
from sklearn.ensemble import RandomForestRegressor

# rf_model = RandomForestRegressor(n_estimators=100, random_state=42)
# rf_model.fit(X_train, y_train)

xgb_model = XGBRegressor(n_estimators=500, random_state=42, reg_alpha=0.1, reg_lambda=1.0)

xgb_model.fit(X_train, y_train)
# Out:
# XGBRegressor(base_score=None, booster=None, callbacks=None,
#              colsample_bylevel=None, colsample_bynode=None,
#              colsample_bytree=None, device=None, early_stopping_rounds=None,
#              enable_categorical=False, eval_metric=None, feature_types=None,
#              gamma=None, grow_policy=None, importance_type=None,
#              interaction_constraints=None, learning_rate=None, max_bin=None,
#              max_cat_threshold=None, max_cat_to_onehot=None,
#              max_delta_step=None, max_depth=None, max_leaves=None,
#              min_child_weight=None, missing=nan, monotone_constraints=None,
#              multi_strategy=None, n_estimators=500, n_jobs=None,
#              num_parallel_tree=None, random_state=42, ...)

# %%
y_pred_2025 = xgb_model.predict(X_forcast_2025)
y_pred_2026 = xgb_model.predict(X_forcast_2026)
y_pred_2027 = xgb_model.predict(X_forcast_2027)

# %%
# indices = np.argsort(importances)[::-1]
# features = X_forcast_2025.columns

# # Renaming feature 'Rate per 100,000 population' to 'crime_rate'
# features = features.str.replace('Rate per 100,000 population', 'crime_rate')

# # Custom colors for different feature categories
# custom_colors = {
#     'internal_features': '#f9d0c8',  # Light rose for house-related features
#     'school_related': '#bd6877',      # Darker pink for school-related features
#     'external_factors': '#4c4557'     # Dark gray for external factors
# }

# # Assign colors to each feature based on their category
# feature_colors = []
# for feature in features:
#     if any(keyword in feature for keyword in ['num_bathrooms', 'num_bedrooms', 'parking', 'year', 'property_type']):
#         feature_colors.append(custom_colors['internal_features'])
#     elif 'secondary' in feature or 'edu' in feature or 'primary' in feature:
#         feature_colors.append(custom_colors['school_related'])
#     else:
#         feature_colors.append(custom_colors['external_factors'])

# # Making feature names more presentable
# features_presentable = features.str.replace('_', ' ').str.title()

# # Plotting
# plt.figure(figsize=(10, 6))
# plt.title("Feature Importances")

# # Bar plot with colors
# plt.bar(range(X_train.shape[1]), importances[indices], align="center", color=feature_colors)

# # Adding x-ticks with feature names
# plt.xticks(range(X_train.shape[1]), features_presentable[indices], rotation=90)

# # Adding labels for the color categories
# internal_patch = plt.Line2D([0], [0], color=custom_colors['internal_features'], lw=4, label='Internal Features')
# school_patch = plt.Line2D([0], [0], color=custom_colors['school_related'], lw=4, label='School Related Features')
# external_patch = plt.Line2D([0], [0], color=custom_colors['external_factors'], lw=4, label='External Factors')

# # Adding legend
# plt.legend(handles=[internal_patch, school_patch, external_patch], title="Feature Categories")

# plt.xlim([-1, X_train.shape[1]])
# plt.show()

# # Print feature ranking
# print("Feature ranking:")
# for f in range(X_train.shape[1]):
#     print(f"{f + 1}. feature {features_presentable[indices[f]]} ({importances[indices[f]]})")


# get the most significant features, using the xgboost model

importances = xgb_model.feature_importances_
indices = np.argsort(importances)[::-1]
features = X_forcast_2025.columns

# Renaming feature 'Rate per 100,000 population' to 'crime_rate'
features = features.str.replace('Rate per 100,000 population', 'crime_rate')

# Custom colors: dark pink for school-related, light gray for the rest
custom_colors = {
    'school_related': '#bd6877',  # Darker pink for school-related features
    'other': '#d3d3d3'            # Light grey for other features
}

# Exact school-related keywords
school_related_keywords = [
    'num_primary', 'num_secondary_public', 'num_secondary_private', 
    'num_secondary_catholic', 'num_edu_centre', 'v_high_vcaa', 
    'high_vcaa', 'good_vcaa'
]

# Assign colors to each feature based on whether it's school-related or not
feature_colors = []
for feature in features:
    # Check if the feature name exactly matches one of the school-related keywords
    if feature in school_related_keywords:
        feature_colors.append(custom_colors['school_related'])
    else:
        feature_colors.append(custom_colors['other'])

# Making feature names more presentable
features_presentable = features.str.replace('_', ' ').str.title()

# Plotting
plt.figure(figsize=(10, 6))
plt.title("Feature Importances")

# Bar plot with colors
plt.bar(range(X_train.shape[1]), importances[indices], align="center", color=feature_colors)

# Adding x-ticks with feature names
plt.xticks(range(X_train.shape[1]), features_presentable[indices], rotation=90)

# Adding legend for the color categories
school_patch = plt.Line2D([0], [0], color=custom_colors['school_related'], lw=4, label='School Related Features')
other_patch = plt.Line2D([0], [0], color=custom_colors['other'], lw=4, label='Other Features')

# Adding legend
plt.legend(handles=[school_patch, other_patch], title="Feature Categories")

plt.xlim([-1, X_train.shape[1]])
plt.show()

# Print feature ranking
print("Feature ranking:")
for f in range(X_train.shape[1]):
    print(f"{f + 1}. feature {features_presentable[indices[f]]} ({importances[indices[f]]})")
# Out:
# Feature ranking:
# 1. feature Avg Rent By Suburb (0.275932639837265)
# 2. feature Num Bathrooms (0.1622692197561264)
# 3. feature V High Vcaa (0.06848254799842834)
# 4. feature Avg Distance To Cbd (0.05892515927553177)
# 5. feature Num Bedrooms (0.0579969584941864)
# 6. feature Property Type Studio (0.04490494355559349)
# 7. feature Property Type Apartment / Unit / Flat (0.042287975549697876)
# 8. feature Year (0.04140375927090645)
# 9. feature Median Rent By Suburb (0.033784836530685425)
# 10. feature Num Secondary Private (0.023814961314201355)
# 11. feature Lga Population (0.022165928035974503)
# 12. feature High Vcaa (0.018914418295025826)
# 13. feature Property Type House (0.018167950212955475)
# 14. feature Num Secondary Catholic (0.015563394874334335)
# 15. feature Crime Rate (0.01403459720313549)
# 16. feature Nearst Train Station Dist (0.013983914628624916)
# 17. feature Parking (0.013698088005185127)
# 18. feature Property Type Townhouse (0.013225743547081947)
# 19. feature Num Secondary Public (0.012739204801619053)
# 20. feature Num Edu Centre (0.011094401590526104)
# 21. feature Num Primary (0.007280279416590929)
# 22. feature Property Type Villa (0.0071862987242639065)
# 23. feature Good Vcaa (0.007006767671555281)
# 24. feature Month (0.005829289555549622)
# 25. feature Property Type Duplex-Semi-Detached (0.0044660987332463264)
# 26. feature Property Type Serviced Apartment (0.003988536074757576)
# 27. feature Property Type Retirement Living (0.0007372690597549081)
# 28. feature Property Type Duplex (0.00011485335562610999)

# %%
forcast_2025 = pd.concat([X_2025_rent.reset_index(drop=True),X_2025_suburb.reset_index(drop=True), pd.Series(y_pred_2025, name='predicted_rent').reset_index(drop=True), X_forcast_2025.reset_index(drop=True)], axis=1)
# predicted rent prices for and the rest of the features for 2025

# %%
forcast_2026 = pd.concat([X_2026_rent.reset_index(drop=True),X_2026_suburb.reset_index(drop=True), pd.Series(y_pred_2026, name='predicted_rent').reset_index(drop=True), X_forcast_2026.reset_index(drop=True)], axis=1)

# %%
forcast_2027 = pd.concat([X_2027_rent.reset_index(drop=True),X_2027_suburb.reset_index(drop=True), pd.Series(y_pred_2027, name='predicted_rent').reset_index(drop=True), X_forcast_2027.reset_index(drop=True)], axis=1)

# %%
aggregated_2026 = forcast_2026[['suburb','predicted_rent','year','rent']].groupby('suburb')['predicted_rent'].mean()
aggregated_2025 = forcast_2025[['suburb','predicted_rent','year','rent']].groupby('suburb')['predicted_rent'].mean()
aggregated_2027 = forcast_2027[['suburb','predicted_rent','year','rent']].groupby('suburb')['predicted_rent'].mean()

# %%
aggregated_2025 = aggregated_2025.reset_index()
aggregated_2025['year'] = 2025


aggregated_2026 = aggregated_2026.reset_index()
aggregated_2026['year'] = 2026

aggregated_2027 = aggregated_2027.reset_index()
aggregated_2027['year'] = 2027

# %%
aggregated_2025
# Out:
#            suburb  predicted_rent  year
# 0      abbotsford      689.704529  2025
# 1      aberfeldie      694.407166  2025
# 2    airport west      576.851501  2025
# 3       albanvale      497.883026  2025
# 4     albert park     1180.227539  2025
# ..            ...             ...   ...
# 583      yarragon      489.035767  2025
# 584        yarram      420.348206  2025
# 585    yarraville      669.289612  2025
# 586    yarrawonga      493.491150  2025
# 587           yea      439.290619  2025
#
# [588 rows x 3 columns]

# %%
aggregated_2025.sort_values(by='suburb', ascending=False, inplace=True)

# %%
aggregated_2027.sort_values(by='suburb', ascending=False, inplace=True)

# %%
aggregated_2026.sort_values(by='suburb', ascending=False, inplace=True)

# %%
diff_2025_2027 = pd.merge(aggregated_2025, aggregated_2027, on='suburb', how='inner')
# calculate the growth rate of the rent prices from 2025 to 2027

diff_2025_2027['growth(%)'] = ((diff_2025_2027['predicted_rent_y'] - diff_2025_2027['predicted_rent_x'])/diff_2025_2027['predicted_rent_x'])*100

diff_2025_2027
# Out:
#            suburb  predicted_rent_x  year_x  predicted_rent_y  year_y  \
# 0             yea        439.290619    2025        439.290619    2027
# 1      yarrawonga        493.491150    2025        494.852783    2027
# 2      yarraville        669.289612    2025        698.839172    2027
# 3          yarram        420.348206    2025        420.348206    2027
# 4        yarragon        489.035767    2025        490.582458    2027
# ..            ...               ...     ...               ...     ...
# 583   albert park       1180.227539    2025       1180.227539    2027
# 584     albanvale        497.883026    2025        497.883026    2027
# 585  airport west        576.851501    2025        576.851501    2027
# 586    aberfeldie        694.407166    2025        694.407166    2027
# 587    abbotsford        689.704529    2025        689.704529    2027
#
#      growth(%)
# 0     0.000000
# 1     0.275918
# 2     4.415063
# 3     0.000000
# 4     0.316274
# ..         ...
# 583   0.000000
# 584   0.000000
# 585   0.000000
# 586   0.000000
# 587   0.000000
#
# [588 rows x 6 columns]

# %%
ranking = diff_2025_2027.sort_values(by='growth(%)', ascending=False)

ranking[ranking['suburb'] == 'doncaster']
# Out:
#         suburb  predicted_rent_x  year_x  predicted_rent_y  year_y  growth(%)
# 416  doncaster        669.156372    2025         664.65509    2027   -0.67268

# %%
# ranking[ranking['suburb'] == 'box hill']

# %%
top_ten_growth_suburbs = ranking[0:10]

# %%
highest_growth_suburb = top_ten_growth_suburbs[['suburb','growth(%)']]
# the top ten suburbs with the highest growth rate 

# now remove the index part 
highest_growth_suburb.reset_index(drop=True, inplace=True)

# %%
highest_growth_suburb
# Out:
#              suburb  growth(%)
# 0          brooklyn   5.530499
# 1          numurkah   5.244390
# 2          pakenham   4.459053
# 3        yarraville   4.415063
# 4  south kingsville   4.376797
# 5           officer   4.265609
# 6      altona north   4.206747
# 7          parkdale   4.199463
# 8            seddon   3.728545
# 9       maribyrnong   3.538973

# %%
top_ten_sub = list(top_ten_growth_suburbs['suburb'].unique())
#

# %%
top_ten_growth_suburbs
# Out:
#                suburb  predicted_rent_x  year_x  predicted_rent_y  year_y  \
# 507          brooklyn        543.607483    2025        573.671692    2027
# 181          numurkah        393.035309    2025        413.647614    2027
# 170          pakenham        579.781921    2025        605.634705    2027
# 2          yarraville        669.289612    2025        698.839172    2027
# 110  south kingsville        601.810608    2025        628.150635    2027
# 174           officer        615.638733    2025        641.899475    2027
# 576      altona north        612.354187    2025        638.114380    2027
# 169          parkdale        678.025879    2025        706.499329    2027
# 119            seddon        649.204163    2025        673.410034    2027
# 254       maribyrnong        572.351685    2025        592.607056    2027
#
#      growth(%)
# 507   5.530499
# 181   5.244390
# 170   4.459053
# 2     4.415063
# 110   4.376797
# 174   4.265609
# 576   4.206747
# 169   4.199463
# 119   3.728545
# 254   3.538973

# %%
#  past rent prices for the top ten suburbs with the highest growth rate
df_sub_timeline  = pd.concat([aggregated_2025, aggregated_2026, aggregated_2027], axis=0)

df_sub_timeline = df_sub_timeline[df_sub_timeline['suburb'].isin(top_ten_sub)]

df_past_timeline = df[df['suburb'].isin(top_ten_sub)]

#  the past rent prices for the top ten suburbs with the highest growth rate

df_past_timeline = df_past_timeline[['suburb','year','rent']].groupby(['suburb','year']).mean()

# %%
df_past_timeline = df_past_timeline.reset_index()

# %%
df_past_timeline
# Out:
#           suburb  year        rent
# 0   altona north  2015  401.497326
# 1   altona north  2016  415.474684
# 2   altona north  2017  439.244186
# 3   altona north  2021  520.000000
# 4   altona north  2022  631.000000
# ..           ...   ...         ...
# 62    yarraville  2020  600.000000
# 63    yarraville  2021  575.000000
# 64    yarraville  2022  642.500000
# 65    yarraville  2023  648.333333
# 66    yarraville  2024  689.500000
#
# [67 rows x 3 columns]

# %%
#  the rent prices for the top ten suburbs with the highest growth rate

df_sub_timeline
df_sub_timeline.rename(columns={'predicted_rent':'rent'}, inplace=True)

# %%
df_join_top_ten = pd.concat([df_past_timeline, df_sub_timeline], axis=0)
df_join_top_ten

#  graph the rent prices for the top ten suburbs with the highest growth rate
# over all the years...
# Out:
#            suburb  year        rent
# 0    altona north  2015  401.497326
# 1    altona north  2016  415.474684
# 2    altona north  2017  439.244186
# 3    altona north  2021  520.000000
# 4    altona north  2022  631.000000
# ..            ...   ...         ...
# 413       officer  2027  641.899475
# 406      numurkah  2027  413.647614
# 333   maribyrnong  2027  592.607056
# 80       brooklyn  2027  573.671692
# 11   altona north  2027  638.114380
#
# [97 rows x 3 columns]

# %%
df_join_top_ten[df_join_top_ten['suburb'] == 'hillside']
# Out:
# Empty DataFrame
# Columns: [suburb, year, rent]
# Index: []

# %%
# plot the top ten suburbs and there rent growth over the years, fill in the missing values with the average of the previous and next year



#  the rent prices for the top ten suburbs with the highest growth rate
sns.lineplot(data=df_join_top_ten, x='year', y='rent', hue='suburb', marker='o')

# Set the title and labels
plt.title('Rent Growth Over Years for Top Ten Suburbs', fontsize=16)
plt.xlabel('Year', fontsize=14)
plt.ylabel('Rent ($)', fontsize=14)

# Show the plot
plt.xticks(rotation=45)  # Rotate x-axis labels for better readability
plt.tight_layout()  # Adjust layout to fit everything neatly
plt.show()

# %%
# the rent prices for the top ten suburbs with the highest growth rate
# over all the years...
u= df.groupby(['suburb',"year"]).count()
u = u.reset_index()
u[u['suburb'] == 'hillside']
# Out:
#         suburb  year  rent  num_bedrooms  num_bathrooms  parking  \
# 1442  hillside  2015   192           192            192      192
# 1443  hillside  2016   167           167            167      167
# 1444  hillside  2017   186           186            186      186
# 1445  hillside  2023     2             2              2        2
# 1446  hillside  2024     6             6              6        6
#
#       nearst_train_station_dist  month  num_primary  num_secondary_public  \
# 1442                        192    192          192                   192
# 1443                        167    167          167                   167
# 1444                        186    186          186                   186
# 1445                          2      2            2                     2
# 1446                          6      6            6                     6
#
#       ...  property_type_serviced apartment  property_type_studio  \
# 1442  ...                               192                   192
# 1443  ...                               167                   167
# 1444  ...                               186                   186
# 1445  ...                                 2                     2
# 1446  ...                                 6                     6
#
#       property_type_townhouse  property_type_villa  lga  \
# 1442                      192                  192  192
# 1443                      167                  167  167
# 1444                      186                  186  186
# 1445                        2                    2    2
# 1446                        6                    6    6
#
#       Rate per 100,000 population  lga_population  avg_distance_to_cbd  \
# 1442                          192             192                  192
# 1443                          167             167                  167
# 1444                          186             186                  186
# 1445                            2               2                    2
# 1446                            6               6                    6
#
#       avg_rent_by_suburb  median_rent_by_suburb
# 1442                 192                    192
# 1443                 167                    167
# 1444                 186                    186
# 1445                   2                      2
# 1446                   6                      6
#
# [5 rows x 31 columns]

# %%
ranking.to_csv('../data/curated/growth_rate_suburb.csv')
