# %%
import pandas as pd

# %%
# Load the Excel file to inspect its contents
file_path = 'data/raw/2023SeniorSecondaryCompletionAndAchievementInformation.xlsx'
excel_data = pd.ExcelFile(file_path)
excel_data

# %%
# Load the relevant sheet into a dataframe, skipping the metadata rows
school_df = pd.read_excel(file_path, sheet_name='postcomp_for_publication', skiprows=8)

# Set the second row (index 1) as the actual column headers
school_df.columns = school_df.iloc[1]  # Set the second row as the headers
school_df = school_df.drop([0, 1])  # Drop the first two rows which contain redundant information

# Dropping any fully empty rows
school_df = school_df.dropna(how='all')

# Resetting the index to clean the dataframe
school_df = school_df.reset_index(drop=True)
school_df
# Out:
# 1                          School Small School         Locality  \
# 0      Academy of Mary Immaculate          NaN          FITZROY
# 1             Adass Israel School          NaN      ELSTERNWICK
# 2             Adass Israel School            *    EAST ST KILDA
# 3    Advance College of Education            *     ROSEBUD WEST
# 4                  Aitken College          NaN        GREENVALE
# ..                            ...          ...              ...
# 593       Yarrawonga College P-12          NaN       YARRAWONGA
# 594               Yea High School          NaN              YEA
# 595              Yeshivah College          NaN    ST KILDA EAST
# 596       Yesodei HaTorah College          NaN           ORMOND
# 597        Youth2Industry College          NaN  SOUTH MELBOURNE
#
# 1   Number of VCE and VCE Vocational Major (VM) studies at Units 3 and 4 level with enrolments   \
# 0                                                   33
# 1                                                    9
# 2                                                    2
# 3                                                   13
# 4                                                   41
# ..                                                 ...
# 593                                                 30
# 594                                                 33
# 595                                                 14
# 596                                                 11
# 597                                                 17
#
# 1   Number of Vocational Education and Training (VET) certificates with enrolments  \
# 0                                                   10
# 1                                                    3
# 2                                                    2
# 3                                                   19
# 4                                                   11
# ..                                                 ...
# 593                                                 21
# 594                                                 12
# 595                                                  2
# 596                                                  4
# 597                                                 22
#
# 1   Number of Higher Education studies (HES) with enrolments  \
# 0                                                    -
# 1                                                    -
# 2                                                    -
# 3                                                    -
# 4                                                    2
# ..                                                 ...
# 593                                                  6
# 594                                                  -
# 595                                                  -
# 596                                                  -
# 597                                                  -
#
# 1   Enrolment(s) in VCE Vocational Major (VM) unit(s)​  \
# 0                                                  NaN
# 1                                                    Y
# 2                                                  NaN
# 3                                                    Y
# 4                                                    Y
# ..                                                 ...
# 593                                                  Y
# 594                                                  Y
# 595                                                NaN
# 596                                                NaN
# 597                                                  Y
#
# 1   Enrolment(s) in the Victorian Pathways Certificate (VPC)  \
# 0                                                  NaN
# 1                                                  NaN
# 2                                                    Y
# 3                                                    Y
# 4                                                  NaN
# ..                                                 ...
# 593                                                NaN
# 594                                                  Y
# 595                                                NaN
# 596                                                NaN
# 597                                                  Y
#
# 1   Enrolment(s) in the International Baccalaureate (IB) Diploma  \
# 0                                                  NaN
# 1                                                  NaN
# 2                                                  NaN
# 3                                                  NaN
# 4                                                  NaN
# ..                                                 ...
# 593                                                NaN
# 594                                                NaN
# 595                                                NaN
# 596                                                NaN
# 597                                                NaN
#
# 1   Enrolment(s) in Northern Hemisphere Timetable (NHT) delivery at Units 3 and 4 level ​  \
# 0                                                  NaN
# 1                                                  NaN
# 2                                                  NaN
# 3                                                  NaN
# 4                                                  NaN
# ..                                                 ...
# 593                                                NaN
# 594                                                NaN
# 595                                                NaN
# 596                                                NaN
# 597                                                NaN
#
# 1    ...  \
# 0    ...
# 1    ...
# 2    ...
# 3    ...
# 4    ...
# ..   ...
# 593  ...
# 594  ...
# 595  ...
# 596  ...
# 597  ...
#
# 1   Number of students enrolled in the Victorian Certificate of Applied Learning (VCAL) at Intermediate level (2023 only)  \
# 0                                                    -
# 1                                                  < 4
# 2                                                  < 4
# 3                                                    -
# 4                                                    -
# ..                                                 ...
# 593                                                < 4
# 594                                                  -
# 595                                                  -
# 596                                                  -
# 597                                                  -
#
# 1   Percentage of satisfactory VCE completions  \
# 0                                           99
# 1                                          100
# 2                                            -
# 3                                           75
# 4                                           99
# ..                                         ...
# 593                                         98
# 594                                         85
# 595                                        100
# 596                                        100
# 597                                         59
#
# 1   Number of students awarded the VCE Vocational Major (VM)  \
# 0                                                    -
# 1                                                   18
# 2                                                    -
# 3                                                  < 4
# 4                                                    5
# ..                                                 ...
# 593                                                 15
# 594                                                  4
# 595                                                  -
# 596                                                  -
# 597                                                 10
#
# 1   Number of students awarded the VCE (Baccalaureate)  \
# 0                                                    8
# 1                                                    -
# 2                                                    -
# 3                                                    -
# 4                                                  < 4
# ..                                                 ...
# 593                                                  -
# 594                                                  -
# 595                                                  -
# 596                                                  -
# 597                                                  -
#
# 1   Percentage of Vocational Education and Training (VET) units of competency completed  \
# 0                                                   98
# 1                                                   82
# 2                                                   76
# 3                                                   59
# 4                                                  100
# ..                                                 ...
# 593                                                 92
# 594                                                 73
# 595                                                 91
# 596                                                 95
# 597                                                 45
#
# 1   Percentage of Higher Education studies (HES) completed  \
# 0                                                    -
# 1                                                    -
# 2                                                    -
# 3                                                    -
# 4                                                  I/D
# ..                                                 ...
# 593                                                I/D
# 594                                                  -
# 595                                                  -
# 596                                                  -
# 597                                                  -
#
# 1   Median VCE study score Percentage of study scores of 40 and over  \
# 0                       31                                      10.3
# 1                        -                                         -
# 2                        -                                         -
# 3                        -                                         -
# 4                       28                                       5.6
# ..                     ...                                       ...
# 593                     26                                       3.7
# 594                     25                                         -
# 595                     34                                      17.9
# 596                     37                                        20
# 597                      -                                         -
#
# 1   Percentage of Victorian Certificate of Applied Learning (VCAL) units completed (2023 only)  \
# 0                                                    -
# 1                                                  I/D
# 2                                                  I/D
# 3                                                    -
# 4                                                    -
# ..                                                 ...
# 593                                                I/D
# 594                                                  -
# 595                                                  -
# 596                                                  -
# 597                                                  -
#
# 1   Number of students awarded the Victorian Pathways Certificate (VPC)
# 0                                                    -
# 1                                                    -
# 2                                                    -
# 3                                                   15
# 4                                                    -
# ..                                                 ...
# 593                                                  -
# 594                                                  -
# 595                                                  -
# 596                                                  -
# 597                                                  6
#
# [598 rows x 25 columns]

# %%
school_df.to_csv("data/curated/vcaa_results.csv")

# %% [markdown]
# # VCAA

# %%
'''
file_path = 'data/curated/vcaa_results.csv'
school_df = pd.read_csv(file_path)
school_df.head()
'''
# Out:
# "\nfile_path = 'data/curated/vcaa_results.csv'\nschool_df = pd.read_csv(file_path)\nschool_df.head()\n"

# %%
# Extract relevant columns: School, Locality (suburb), and Percentage of study scores of 40 and over
extracted_data = school_df[['School', 'Locality', 'Percentage of study scores of 40 and over']]

# Renaming the columns to make them shorter and more readable
school_df = extracted_data.rename(columns={
    'School': 'school',
    'Locality': 'suburb',
    'Percentage of study scores of 40 and over': 'pct_scores_40_over'
})

# Handling missing or invalid data in 'Pct_Scores_40_Over' by replacing '-' with NaN
school_df['pct_scores_40_over'] = pd.to_numeric(school_df['pct_scores_40_over'], errors='coerce')

# %%
school_df
# Out:
# 1                          school           suburb  pct_scores_40_over
# 0      Academy of Mary Immaculate          FITZROY                10.3
# 1             Adass Israel School      ELSTERNWICK                 NaN
# 2             Adass Israel School    EAST ST KILDA                 NaN
# 3    Advance College of Education     ROSEBUD WEST                 NaN
# 4                  Aitken College        GREENVALE                 5.6
# ..                            ...              ...                 ...
# 593       Yarrawonga College P-12       YARRAWONGA                 3.7
# 594               Yea High School              YEA                 NaN
# 595              Yeshivah College    ST KILDA EAST                17.9
# 596       Yesodei HaTorah College           ORMOND                20.0
# 597        Youth2Industry College  SOUTH MELBOURNE                 NaN
#
# [598 rows x 3 columns]

# %%
school_df['school'] = school_df['school'].str.lower()
school_df['suburb'] = school_df['suburb'].str.lower()

# Sorting the data by 'Pct_Scores_40_Over' in descending order and creating a rank column
school_df = school_df.sort_values(by='pct_scores_40_over', ascending=False).reset_index(drop=True)
school_df['rank'] = school_df['pct_scores_40_over'].rank(method='min', ascending=False)
school_df
# Out:
# 1                              school           suburb  pct_scores_40_over  \
# 0          ballarat clarendon college         ballarat                45.8
# 1                      bialik college         hawthorn                34.1
# 2                 huntingtower school   mount waverley                33.8
# 3       mount scopus memorial college          burwood                31.5
# 4                ruyton girls' school              kew                31.4
# ..                                ...              ...                 ...
# 593        wyndham comm & educ centre         werribee                 NaN
# 594    yarra hills sec coll mt evelyn     mount evelyn                 NaN
# 595  yarra hills sec coll mooroolbark      mooroolbark                 NaN
# 596                   yea high school              yea                 NaN
# 597            youth2industry college  south melbourne                 NaN
#
# 1    rank
# 0     1.0
# 1     2.0
# 2     3.0
# 3     4.0
# 4     5.0
# ..    ...
# 593   NaN
# 594   NaN
# 595   NaN
# 596   NaN
# 597   NaN
#
# [598 rows x 4 columns]

# %%
# Define thresholds for "Good", "Mid", and "Bad" schools based on the pct_scores_40_over
def categorize_school(pct_scores_40_over):
    if pct_scores_40_over > 15:
        return 'high'
    elif pct_scores_40_over >= 10:
        return 'good'
    elif pct_scores_40_over >= 4.5:
        return 'mid'
    else:
        return 'low'

# Apply the categorization function to create a new column 'school_quality'
school_df['school_quality'] = school_df['pct_scores_40_over'].apply(categorize_school)

# %%
school_df
# Out:
# 1                              school           suburb  pct_scores_40_over  \
# 0          ballarat clarendon college         ballarat                45.8
# 1                      bialik college         hawthorn                34.1
# 2                 huntingtower school   mount waverley                33.8
# 3       mount scopus memorial college          burwood                31.5
# 4                ruyton girls' school              kew                31.4
# ..                                ...              ...                 ...
# 593        wyndham comm & educ centre         werribee                 NaN
# 594    yarra hills sec coll mt evelyn     mount evelyn                 NaN
# 595  yarra hills sec coll mooroolbark      mooroolbark                 NaN
# 596                   yea high school              yea                 NaN
# 597            youth2industry college  south melbourne                 NaN
#
# 1    rank school_quality
# 0     1.0           high
# 1     2.0           high
# 2     3.0           high
# 3     4.0           high
# 4     5.0           high
# ..    ...            ...
# 593   NaN            low
# 594   NaN            low
# 595   NaN            low
# 596   NaN            low
# 597   NaN            low
#
# [598 rows x 5 columns]

# %%
school_df.to_csv("data/curated/vcaa_ranking.csv")

# %%
file_path = 'data/curated/vcaa_ranking.csv'
school_df = pd.read_csv(file_path)
school_df.head()
# Out:
#    Unnamed: 0                         school          suburb  \
# 0           0     ballarat clarendon college        ballarat
# 1           1                 bialik college        hawthorn
# 2           2            huntingtower school  mount waverley
# 3           3  mount scopus memorial college         burwood
# 4           4           ruyton girls' school             kew
#
#    pct_scores_40_over  rank school_quality
# 0                45.8   1.0           high
# 1                34.1   2.0           high
# 2                33.8   3.0           high
# 3                31.5   4.0           high
# 4                31.4   5.0           high

# %%
aggregated_data = school_df.groupby(['suburb', 'school_quality']).size().unstack(fill_value=0)
aggregated_data
# Out:
# school_quality  good  high  low  mid
# suburb
# aberfeldie         0     0    0    1
# albert park        0     0    0    1
# alexandra          0     0    1    0
# alphington         0     1    0    0
# altona             0     0    1    1
# ...              ...   ...  ...  ...
# wyndham vale       0     0    1    0
# yarra junction     0     0    2    1
# yarram             0     0    1    0
# yarrawonga         0     0    2    0
# yea                0     0    1    0
#
# [357 rows x 4 columns]

# %%
aggregated_data = aggregated_data[['high', 'good', 'mid']]
aggregated_data
# Out:
# school_quality  high  good  mid
# suburb
# aberfeldie         0     0    1
# albert park        0     0    1
# alexandra          0     0    0
# alphington         1     0    0
# altona             0     0    1
# ...              ...   ...  ...
# wyndham vale       0     0    0
# yarra junction     0     0    1
# yarram             0     0    0
# yarrawonga         0     0    0
# yea                0     0    0
#
# [357 rows x 3 columns]

# %%
aggregated_data.to_csv("data/curated/num_good_schools.csv")

# %% [markdown]
# # Merge with schools by suburb

# %%
file_path = 'data/curated/num_good_schools.csv'
school_quality_df = pd.read_csv(file_path)
school_quality_df.head()
# Out:
#         suburb  high  good  mid
# 0   aberfeldie     0     0    1
# 1  albert park     0     0    1
# 2    alexandra     0     0    0
# 3   alphington     1     0    0
# 4       altona     0     0    1

# %%
file_path = 'data/curated/schools_by_suburb.csv'
school_type_df = pd.read_csv(file_path)
school_type_df.head()
# Out:
#    Unnamed: 0  Address_Town  num_primary  num_secondary_public  \
# 0           0    Abbotsford            2                     0
# 1           1    Aberfeldie            1                     0
# 2           2       Aintree            1                     0
# 3           3  Aireys Inlet            1                     0
# 4           4         Airly            1                     0
#
#    num_secondary_private  num_secondary_catholic  num_special
# 0                      1                       0            0
# 1                      0                       1            0
# 2                      0                       0            0
# 3                      0                       0            0
# 4                      0                       0            0

# %%
school_type_df['Address_Town'] = school_type_df['Address_Town'].str.lower()
merged_df = school_quality_df.merge(school_type_df, left_on='suburb', right_on='Address_Town', how='inner')
merged_df.head()
# Out:
#         suburb  high  good  mid  Unnamed: 0 Address_Town  num_primary  \
# 0   aberfeldie     0     0    1           1   aberfeldie            1
# 1  albert park     0     0    1           7  albert park            2
# 2    alexandra     0     0    0          10    alexandra            2
# 3   alphington     1     0    0          13   alphington            3
# 4       altona     0     0    1          14       altona            3
#
#    num_secondary_public  num_secondary_private  num_secondary_catholic  \
# 0                     0                      0                       1
# 1                     1                      0                       0
# 2                     1                      0                       0
# 3                     0                      1                       0
# 4                     1                      0                       1
#
#    num_special
# 0            0
# 1            0
# 2            0
# 3            0
# 4            0

# %%
# Dropping the 'Unnamed: 0' and 'Address_Town' columns
merged_df = merged_df.drop(columns=['Unnamed: 0', 'Address_Town'])

# Renaming the columns 'high', 'good', and 'mid'
merged_df = merged_df.rename(columns={
    'high': 'v_high_vcaa',
    'good': 'high_vcaa',
    'mid': 'good_vcaa',
    'num_special': 'num_edu_centre'
})

# Displaying the first few rows to confirm changes
merged_df.head()
# Out:
#         suburb  v_high_vcaa  high_vcaa  good_vcaa  num_primary  \
# 0   aberfeldie            0          0          1            1
# 1  albert park            0          0          1            2
# 2    alexandra            0          0          0            2
# 3   alphington            1          0          0            3
# 4       altona            0          0          1            3
#
#    num_secondary_public  num_secondary_private  num_secondary_catholic  \
# 0                     0                      0                       1
# 1                     1                      0                       0
# 2                     1                      0                       0
# 3                     0                      1                       0
# 4                     1                      0                       1
#
#    num_edu_centre
# 0               0
# 1               0
# 2               0
# 3               0
# 4               0

# %% [markdown]
# VCAA stands for Victorian Curriculum and Assessment Authority
# v_high_vcaa means number of schools that get very high study score (VCE exams)

# %%
merged_df.to_csv("data/curated/schools_preprocessed.csv")
